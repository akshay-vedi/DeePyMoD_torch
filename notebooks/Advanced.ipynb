# %% [markdown]
# # Example Burgers' equation

# %% [markdown]
# In this notebook we provide a simple example of the DeepMoD algorithm by applying it on the Burgers' equation.
#
# We start by importing the required libraries and setting the plotting style:

# %%
import numpy as np
import torch
from deepymod_torch.library_function import *
from deepymod_torch.DeepMod import DeepMoD
from deepymod_torch.neural_net import *
from deepymod_torch.sparsity import *

import matplotlib.pyplot as plt
from scipy.io import loadmat
plt.style.use('seaborn-notebook')

np.random.seed(40)
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Next, we prepare the dataset.

# %%
data_1 =  loadmat('../data/processed/Diffusion_group_2.mat')
usol = np.real(data_1['Expression1'])
usol= usol.reshape((201,201,3))

x_1 = usol[:,:,0]
t_1 = usol[:,:,1]
y_1 = usol[:,:,2]

data_2 = loadmat('../data/processed/Diffusion_group_1.mat')
usol_2 = np.real(data_2['Expression1'])
usol_2 = usol_2.reshape((201,201,3))

x_2 = usol_2[:,:,0]
t_2 = usol_2[:,:,1]
y_2 = usol_2[:,:,2]

# %%
X = np.transpose((t_1.flatten(),x_1.flatten()))
y = np.transpose((y_2.flatten(),y_1.flatten(),y_2.flatten(),y_1.flatten(),y_2.flatten(),y_1.flatten(),y_1.flatten(),y_2.flatten(),y_1.flatten(),y_2.flatten(),y_2.flatten(),y_1.flatten(),y_2.flatten(),y_1.flatten(),y_2.flatten()))

# %%
y.shape
# Out:
# (40401, 15)

# %%
number_of_samples = 30

idx = np.random.permutation(y.shape[0])
X_train = torch.tensor(X[idx, :][:number_of_samples], dtype=torch.float32, requires_grad=True)
y_train = torch.tensor(y[idx, :][:number_of_samples], dtype=torch.float32)

# %%
print(X_train.shape, y_train.shape)
# Out:
# torch.Size([30, 2]) torch.Size([30, 15])

# %% [markdown]
# ## Configure the neural network

# %% [markdown]
# We now setup the options for DeepMoD. There's as few dictionaries to fill, starting with the 'optim config', which sets the maximal number of iterations and the amplitude of the $L_1$ penalty

# %%
optim_config = {'lambda': 10**-5, 'max_iterations': 25000, 'type': 'mse'}

# %% [markdown]
# Next we choose the size of the neural network

# %%
network_config = {'input_dim': 2, 'hidden_dim': 20, 'layers': 4, 'output_dim': y_train.shape[1]}

# %% [markdown]
# DeepMoD accepts any arbitrary library function and any options for it can be given through *the library_config*. The library function for the burgers case accepts a maximum order for the polynomial and derivative terms.

# %%
library_config = {'type': library_1D_in_group_b, 'poly_order': 1, 'diff_order': 2}

# %% [markdown]
# ## Run DeepMoD

# %%
network, coeff_vector_list, sparsity_mask_list = deepmod_init(network_config, library_config)
# Out:
# 15

# %%
time_deriv_list, theta, coeff_vector_list = train_group(X_train, y_train, network, coeff_vector_list, sparsity_mask_list, library_config, optim_config)
# Out:
# Epoch | Total loss | MSE | PI | L1
# 0 1.1E+01 1.6E+00 9.2E+00 1.0E-02
# tensor([[ 0.7482],
#         [ 2.6924],
#         [-1.3109],
#         [-1.3436],
#         [-0.6675],
#         [-0.8647]], requires_grad=True)
# tensor([[ 0.4425],
#         [ 0.6750],
#         [ 0.3800],
#         [-0.4586],
#         [ 0.1590],
#         [-0.7005]], requires_grad=True)
# tensor([[-0.0204],
#         [ 0.2223],
#         [ 0.1763],
#         [-0.7301],
#         [-1.2403],
#         [-0.2199]], requires_grad=True)
# tensor([[ 0.9908],
#         [-1.3532],
#         [ 1.2714],
#         [-0.4181],
#         [-0.1549],
#         [-0.2372]], requires_grad=True)
# tensor([[ 0.3605],
#         [ 1.6531],
#         [-1.8344],
#         [ 1.2912],
#         [ 1.4333],
#         [ 2.0937]], requires_grad=True)
# tensor([[-1.1231],
#         [-0.4607],
#         [-0.5719],
#         [-1.0484],
#         [-0.4245],
#         [ 1.2504]], requires_grad=True)
# tensor([[ 1.3532],
#         [-0.7071],
#         [-0.1632],
#         [-0.8072],
#         [-0.1093],
#         [ 0.7072]], requires_grad=True)
# tensor([[-0.5392],
#         [-0.1613],
#         [-0.0507],
#         [ 1.3020],
#         [-0.6670],
#         [-0.4272]], requires_grad=True)
# tensor([[-1.6330],
#         [-0.1015],
#         [ 0.2117],
#         [-0.3312],
#         [-0.6617],
#         [-1.3412]], requires_grad=True)
# tensor([[ 0.6282],
#         [ 0.4540],
#         [-0.6694],
#         [ 0.7067],
#         [-1.6378],
#         [ 1.2884]], requires_grad=True)
# tensor([[-0.3706],
#         [-0.0388],
#         [ 0.7104],
#         [-1.1097],
#         [ 1.6660],
#         [ 1.3157]], requires_grad=True)
# tensor([[-0.1184],
#         [ 0.0456],
#         [ 1.3081],
#         [ 0.8818],
#         [ 0.3191],
#         [ 0.9024]], requires_grad=True)
# tensor([[-0.1356],
#         [-2.3365],
#         [-0.1052],
#         [-0.5410],
#         [-0.3597],
#         [-0.4597]], requires_grad=True)
# tensor([[ 0.4119],
#         [ 1.8705],
#         [ 0.3460],
#         [ 1.6184],
#         [ 0.5703],
#         [-0.4657]], requires_grad=True)
# tensor([[-1.3240],
#         [ 0.2171],
#         [ 0.4923],
#         [ 0.5166],
#         [-0.6074],
#         [-1.2890]], requires_grad=True)
# 500 6.0E-01 3.7E-01 2.3E-01 4.7E-04
# tensor([[ 0.4013],
#         [ 2.6210],
#         [-1.3587],
#         [-1.8029],
#         [-0.8416],
#         [-0.5587]], requires_grad=True)
# tensor([[ 0.1711],
#         [-0.2088],
#         [ 0.3140],
#         [-0.6553],
#         [-0.2194],
#         [ 0.0938]], requires_grad=True)
# tensor([[ 0.0854],
#         [ 0.1557],
#         [ 0.1349],
#         [-0.4993],
#         [-1.0419],
#         [ 0.0921]], requires_grad=True)
# tensor([[ 0.5992],
#         [-1.7331],
#         [ 1.6089],
#         [-0.8535],
#         [-0.5440],
#         [ 0.1792]], requires_grad=True)
# tensor([[-0.1211],
#         [ 1.8117],
#         [-2.1104],
#         [ 0.9278],
#         [ 1.5246],
#         [ 1.4575]], requires_grad=True)
# tensor([[-0.4993],
#         [-1.1793],
#         [ 0.4083],
#         [-1.4117],
#         [-0.1301],
#         [ 0.3289]], requires_grad=True)
# tensor([[ 0.9328],
#         [-1.4248],
#         [ 0.8408],
#         [-1.2362],
#         [-0.5185],
#         [ 1.4819]], requires_grad=True)
# tensor([[-0.2525],
#         [-0.3887],
#         [ 0.7719],
#         [ 1.4385],
#         [-0.8537],
#         [ 0.3029]], requires_grad=True)
# tensor([[-1.0983],
#         [-1.0475],
#         [ 1.2685],
#         [-0.7887],
#         [-0.9356],
#         [-2.0447]], requires_grad=True)
# tensor([[ 0.0165],
#         [ 0.6299],
#         [ 0.5193],
#         [ 0.8665],
#         [-1.9661],
#         [ 1.2200]], requires_grad=True)
# tensor([[ 0.0777],
#         [-0.5262],
#         [ 0.1797],
#         [-0.6443],
#         [ 1.0837],
#         [ 0.5976]], requires_grad=True)
# tensor([[-0.1126],
#         [-0.2750],
#         [ 1.0032],
#         [ 0.5352],
#         [ 0.0901],
#         [ 0.3037]], requires_grad=True)
# tensor([[ 0.0687],
#         [-1.3788],
#         [ 0.6226],
#         [-0.3881],
#         [ 0.6241],
#         [ 0.0755]], requires_grad=True)
# tensor([[-0.1953],
#         [ 1.0819],
#         [ 1.4272],
#         [ 1.1686],
#         [-0.6344],
#         [ 0.5958]], requires_grad=True)
# tensor([[-0.7394],
#         [-0.4137],
#         [ 1.1601],
#         [ 1.0166],
#         [-1.1487],
#         [-0.8132]], requires_grad=True)
# 1000 1.5E-01 9.8E-02 5.3E-02 6.0E-04
# tensor([[ 0.3118],
#         [ 2.7175],
#         [-1.4025],
#         [-1.8356],
#         [-0.7628],
#         [-0.6487]], requires_grad=True)
# tensor([[ 0.1329],
#         [-0.4641],
#         [ 0.0810],
#         [-0.4810],
#         [ 0.5711],
#         [ 0.2874]], requires_grad=True)
# tensor([[ 0.0733],
#         [ 0.1661],
#         [ 0.1700],
#         [-0.4109],
#         [-1.0489],
#         [-0.1843]], requires_grad=True)
# tensor([[ 0.5105],
#         [-1.7656],
#         [ 1.4262],
#         [-0.9227],
#         [-0.5172],
#         [ 0.4054]], requires_grad=True)
# tensor([[-0.1437],
#         [ 1.7888],
#         [-1.4223],
#         [ 0.7458],
#         [ 1.3288],
#         [ 1.6285]], requires_grad=True)
# tensor([[-0.1929],
#         [-1.3495],
#         [ 0.8641],
#         [-1.3629],
#         [-0.5074],
#         [ 0.1765]], requires_grad=True)
# tensor([[ 0.7977],
#         [-1.6479],
#         [ 1.0643],
#         [-1.3038],
#         [-0.5291],
#         [ 1.4151]], requires_grad=True)
# tensor([[-0.2309],
#         [-0.6523],
#         [ 0.9880],
#         [ 1.3487],
#         [-1.3002],
#         [ 0.0179]], requires_grad=True)
# tensor([[-0.8615],
#         [-1.4036],
#         [ 1.7879],
#         [-0.8301],
#         [-0.8901],
#         [-1.9853]], requires_grad=True)
# tensor([[-0.0948],
#         [ 0.5566],
#         [ 0.6493],
#         [ 0.6711],
#         [-1.9708],
#         [ 0.9516]], requires_grad=True)
# tensor([[ 0.0996],
#         [-0.4601],
#         [ 0.2931],
#         [-0.5275],
#         [ 1.0561],
#         [ 0.4094]], requires_grad=True)
# tensor([[-0.0395],
#         [-0.2975],
#         [ 0.8634],
#         [ 0.2803],
#         [ 0.0428],
#         [ 0.3456]], requires_grad=True)
# tensor([[ 0.0817],
#         [-1.1781],
#         [ 0.7602],
#         [-0.4019],
#         [ 0.7484],
#         [-0.2721]], requires_grad=True)
# tensor([[-0.1790],
#         [ 0.7742],
#         [ 1.5057],
#         [ 0.8637],
#         [-0.8685],
#         [ 0.3444]], requires_grad=True)
# tensor([[-0.4940],
#         [-0.6190],
#         [ 1.3511],
#         [ 1.1421],
#         [-1.2801],
#         [-0.7552]], requires_grad=True)
# 1500 6.9E-02 5.2E-02 1.6E-02 5.1E-04
# tensor([[ 0.2946],
#         [ 2.5757],
#         [-1.5938],
#         [-1.8126],
#         [-0.8402],
#         [-0.9046]], requires_grad=True)
# tensor([[ 0.1093],
#         [-0.5935],
#         [ 0.2718],
#         [-0.3289],
#         [ 0.8026],
#         [ 0.2955]], requires_grad=True)
# tensor([[ 0.0421],
#         [ 0.1795],
#         [ 0.2769],
#         [-0.2578],
#         [-0.9107],
#         [-0.3240]], requires_grad=True)
# tensor([[ 0.4728],
#         [-1.7045],
#         [ 1.5622],
#         [-0.9441],
#         [-0.4574],
#         [ 0.3955]], requires_grad=True)
# tensor([[-0.1364],
#         [ 1.7174],
#         [-1.1192],
#         [ 0.6515],
#         [ 1.1135],
#         [ 1.3627]], requires_grad=True)
# tensor([[-0.0532],
#         [-1.5201],
#         [ 0.9319],
#         [-1.2674],
#         [-0.8483],
#         [ 0.1329]], requires_grad=True)
# tensor([[ 0.7338],
#         [-1.7615],
#         [ 1.2655],
#         [-1.3201],
#         [-0.5571],
#         [ 1.3438]], requires_grad=True)
# tensor([[-0.2180],
#         [-0.7243],
#         [ 1.2501],
#         [ 1.2318],
#         [-1.1591],
#         [-0.3857]], requires_grad=True)
# tensor([[-0.7430],
#         [-1.6666],
#         [ 1.9830],
#         [-0.7815],
#         [-1.1910],
#         [-1.7710]], requires_grad=True)
# tensor([[-0.1000],
#         [ 0.5602],
#         [ 0.7291],
#         [ 0.6210],
#         [-1.8010],
#         [ 0.4782]], requires_grad=True)
# tensor([[ 0.0936],
#         [-0.5006],
#         [ 0.4091],
#         [-0.4752],
#         [ 0.7121],
#         [ 0.1273]], requires_grad=True)
# tensor([[-0.0031],
#         [-0.1614],
#         [ 0.2877],
#         [ 0.0853],
#         [ 0.1499],
#         [ 0.4290]], requires_grad=True)
# tensor([[ 0.0727],
#         [-1.0837],
#         [ 0.7558],
#         [-0.3663],
#         [ 0.7055],
#         [-0.3187]], requires_grad=True)
# tensor([[-0.1236],
#         [ 0.5939],
#         [ 1.2808],
#         [ 0.6469],
#         [-0.7989],
#         [ 0.1712]], requires_grad=True)
# tensor([[-0.3742],
#         [-0.7391],
#         [ 1.4425],
#         [ 1.1829],
#         [-1.3275],
#         [-0.7417]], requires_grad=True)
# 2000 4.2E-02 3.3E-02 8.3E-03 4.8E-04
# tensor([[ 0.3098],
#         [ 2.5446],
#         [-1.7797],
#         [-1.7636],
#         [-0.7818],
#         [-1.1431]], requires_grad=True)
# tensor([[ 0.0782],
#         [-0.5304],
#         [ 0.3296],
#         [-0.2184],
#         [ 0.8613],
#         [ 0.0365]], requires_grad=True)
# tensor([[ 0.0206],
#         [ 0.0134],
#         [ 0.4705],
#         [-0.1423],
#         [-0.6632],
#         [-0.5013]], requires_grad=True)
# tensor([[ 0.4507],
#         [-1.7123],
#         [ 1.6458],
#         [-0.9462],
#         [-0.4294],
#         [ 0.3528]], requires_grad=True)
# tensor([[-0.1195],
#         [ 1.5949],
#         [-1.0226],
#         [ 0.5498],
#         [ 0.9470],
#         [ 1.1322]], requires_grad=True)
# tensor([[ 0.0529],
#         [-1.6937],
#         [ 0.9473],
#         [-1.1612],
#         [-1.1511],
#         [ 0.1609]], requires_grad=True)
# tensor([[ 0.6831],
#         [-1.8364],
#         [ 1.3989],
#         [-1.3268],
#         [-0.5445],
#         [ 1.3261]], requires_grad=True)
# tensor([[-0.2046],
#         [-1.0386],
#         [ 1.4711],
#         [ 1.1125],
#         [-1.0662],
#         [-0.7586]], requires_grad=True)
# tensor([[-0.6346],
#         [-1.8997],
#         [ 2.1348],
#         [-0.7243],
#         [-1.4879],
#         [-1.6319]], requires_grad=True)
# tensor([[-0.0938],
#         [ 0.4542],
#         [ 0.8694],
#         [ 0.5733],
#         [-1.8540],
#         [ 0.3350]], requires_grad=True)
# tensor([[ 0.0786],
#         [-0.5392],
#         [ 0.4843],
#         [-0.4240],
#         [ 0.3896],
#         [-0.0228]], requires_grad=True)
# tensor([[ 0.0112],
#         [-0.1351],
#         [ 0.0859],
#         [-0.0091],
#         [ 0.1736],
#         [ 0.4162]], requires_grad=True)
# tensor([[ 0.0590],
#         [-0.9853],
#         [ 0.6568],
#         [-0.2954],
#         [ 0.6921],
#         [-0.2182]], requires_grad=True)
# tensor([[-0.0833],
#         [ 0.4668],
#         [ 1.0450],
#         [ 0.4516],
#         [-0.7367],
#         [ 0.0800]], requires_grad=True)
# tensor([[-0.3048],
#         [-0.7983],
#         [ 1.4791],
#         [ 1.2039],
#         [-1.3487],
#         [-0.7242]], requires_grad=True)
# 2500 3.1E-02 2.3E-02 7.9E-03 4.4E-04
# tensor([[ 0.3126],
#         [ 2.6211],
#         [-1.8148],
#         [-1.7253],
#         [-0.7307],
#         [-1.3592]], requires_grad=True)
# tensor([[ 0.0479],
#         [-0.3966],
#         [ 0.2744],
#         [-0.1448],
#         [ 0.7403],
#         [-0.2125]], requires_grad=True)
# tensor([[ 0.0160],
#         [-0.1336],
#         [ 0.5244],
#         [-0.1122],
#         [-0.3099],
#         [-0.5133]], requires_grad=True)
# tensor([[ 0.4389],
#         [-1.7340],
#         [ 1.6532],
#         [-0.9375],
#         [-0.3917],
#         [ 0.3540]], requires_grad=True)
# tensor([[-0.1020],
#         [ 1.5455],
#         [-0.9933],
#         [ 0.4444],
#         [ 0.9307],
#         [ 0.9390]], requires_grad=True)
# tensor([[ 0.1289],
#         [-1.7920],
#         [ 0.9519],
#         [-1.0615],
#         [-1.3082],
#         [ 0.2215]], requires_grad=True)
# tensor([[ 0.6459],
#         [-1.8988],
#         [ 1.4649],
#         [-1.3250],
#         [-0.5361],
#         [ 1.3014]], requires_grad=True)
# tensor([[-0.1912],
#         [-1.1874],
#         [ 1.6044],
#         [ 1.0205],
#         [-0.9373],
#         [-1.0164]], requires_grad=True)
# tensor([[-0.5262],
#         [-2.0918],
#         [ 2.2474],
#         [-0.6542],
#         [-1.7591],
#         [-1.5455]], requires_grad=True)
# tensor([[-0.0861],
#         [ 0.3191],
#         [ 0.9293],
#         [ 0.5183],
#         [-1.9992],
#         [ 0.2214]], requires_grad=True)
# tensor([[ 6.3951e-02],
#         [-5.5402e-01],
#         [ 4.8689e-01],
#         [-3.5649e-01],
#         [ 2.7904e-01],
#         [ 1.9094e-04]], requires_grad=True)
# tensor([[ 0.0142],
#         [-0.1080],
#         [ 0.0807],
#         [-0.0404],
#         [ 0.0822],
#         [ 0.2498]], requires_grad=True)
# tensor([[ 0.0410],
#         [-0.8452],
#         [ 0.5701],
#         [-0.2091],
#         [ 0.7526],
#         [-0.1250]], requires_grad=True)
# tensor([[-0.0502],
#         [ 0.2941],
#         [ 0.7236],
#         [ 0.2700],
#         [-0.6578],
#         [ 0.0136]], requires_grad=True)
# tensor([[-0.2649],
#         [-0.8331],
#         [ 1.4882],
#         [ 1.2138],
#         [-1.3599],
#         [-0.7182]], requires_grad=True)
# 3000 1.9E-02 1.5E-02 3.5E-03 3.9E-04
# tensor([[ 0.3092],
#         [ 2.6747],
#         [-1.8014],
#         [-1.6947],
#         [-0.7014],
#         [-1.4724]], requires_grad=True)
# tensor([[ 0.0293],
#         [-0.2746],
#         [ 0.2297],
#         [-0.1027],
#         [ 0.4748],
#         [-0.2312]], requires_grad=True)
# tensor([[ 0.0120],
#         [-0.2356],
#         [ 0.5344],
#         [-0.0962],
#         [-0.0256],
#         [-0.4462]], requires_grad=True)
# tensor([[ 0.4314],
#         [-1.7705],
#         [ 1.6163],
#         [-0.9236],
#         [-0.3503],
#         [ 0.3722]], requires_grad=True)
# tensor([[-0.0848],
#         [ 1.5434],
#         [-0.9714],
#         [ 0.3441],
#         [ 0.9529],
#         [ 0.7003]], requires_grad=True)
# tensor([[ 0.1776],
#         [-1.8108],
#         [ 0.9859],
#         [-0.9762],
#         [-1.3545],
#         [ 0.3006]], requires_grad=True)
# tensor([[ 0.6184],
#         [-1.9574],
#         [ 1.4875],
#         [-1.3165],
#         [-0.5272],
#         [ 1.2648]], requires_grad=True)
# tensor([[-0.1796],
#         [-1.2003],
#         [ 1.6206],
#         [ 0.9440],
#         [-0.7911],
#         [-1.1258]], requires_grad=True)
# tensor([[-0.4183],
#         [-2.2481],
#         [ 2.3255],
#         [-0.5738],
#         [-1.9937],
#         [-1.4872]], requires_grad=True)
# tensor([[-0.0782],
#         [ 0.1844],
#         [ 0.9458],
#         [ 0.4592],
#         [-2.1290],
#         [ 0.1518]], requires_grad=True)
# tensor([[ 0.0481],
#         [-0.5371],
#         [ 0.4516],
#         [-0.2825],
#         [ 0.3130],
#         [ 0.0942]], requires_grad=True)
# tensor([[ 0.0124],
#         [-0.0755],
#         [ 0.1233],
#         [-0.0456],
#         [ 0.0206],
#         [ 0.0948]], requires_grad=True)
# tensor([[ 0.0260],
#         [-0.7223],
#         [ 0.5397],
#         [-0.1478],
#         [ 0.7903],
#         [-0.1471]], requires_grad=True)
# tensor([[-0.0223],
#         [ 0.1427],
#         [ 0.4168],
#         [ 0.1148],
#         [-0.4789],
#         [ 0.0501]], requires_grad=True)
# tensor([[-0.2443],
#         [-0.8558],
#         [ 1.4988],
#         [ 1.2158],
#         [-1.3658],
#         [-0.7135]], requires_grad=True)
# 3500 1.3E-02 1.1E-02 2.2E-03 3.5E-04
# tensor([[ 0.3033],
#         [ 2.6823],
#         [-1.7706],
#         [-1.6671],
#         [-0.6552],
#         [-1.5146]], requires_grad=True)
# tensor([[ 0.0197],
#         [-0.1620],
#         [ 0.1832],
#         [-0.0817],
#         [ 0.2388],
#         [-0.1455]], requires_grad=True)
# tensor([[ 0.0088],
#         [-0.2909],
#         [ 0.5382],
#         [-0.0836],
#         [ 0.1437],
#         [-0.3699]], requires_grad=True)
# tensor([[ 0.4246],
#         [-1.8124],
#         [ 1.5795],
#         [-0.9059],
#         [-0.3032],
#         [ 0.3855]], requires_grad=True)
# tensor([[-0.0670],
#         [ 1.5477],
#         [-0.9614],
#         [ 0.2459],
#         [ 0.9569],
#         [ 0.4514]], requires_grad=True)
# tensor([[ 0.2134],
#         [-1.7754],
#         [ 1.0461],
#         [-0.8974],
#         [-1.3464],
#         [ 0.3708]], requires_grad=True)
# tensor([[ 0.5987],
#         [-2.0143],
#         [ 1.4944],
#         [-1.3007],
#         [-0.5151],
#         [ 1.2133]], requires_grad=True)
# tensor([[-0.1674],
#         [-1.1531],
#         [ 1.5802],
#         [ 0.8726],
#         [-0.6305],
#         [-1.1414]], requires_grad=True)
# tensor([[-0.3132],
#         [-2.3651],
#         [ 2.3688],
#         [-0.4876],
#         [-2.1688],
#         [-1.4686]], requires_grad=True)
# tensor([[-0.0706],
#         [ 0.0607],
#         [ 0.9421],
#         [ 0.4020],
#         [-2.1903],
#         [ 0.1620]], requires_grad=True)
# tensor([[ 0.0340],
#         [-0.4827],
#         [ 0.4181],
#         [-0.2199],
#         [ 0.3676],
#         [ 0.1491]], requires_grad=True)
# tensor([[ 1.1632e-02],
#         [-5.2386e-02],
#         [ 1.4442e-01],
#         [-4.8767e-02],
#         [ 1.0737e-04],
#         [ 2.6711e-02]], requires_grad=True)
# tensor([[ 0.0157],
#         [-0.6254],
#         [ 0.5443],
#         [-0.1103],
#         [ 0.7952],
#         [-0.2067]], requires_grad=True)
# tensor([[-0.0012],
#         [ 0.0532],
#         [ 0.1943],
#         [ 0.0088],
#         [-0.2810],
#         [ 0.1314]], requires_grad=True)
# tensor([[-0.2345],
#         [-0.8641],
#         [ 1.5238],
#         [ 1.2128],
#         [-1.3648],
#         [-0.7039]], requires_grad=True)
# 4000 9.6E-03 7.7E-03 1.6E-03 3.2E-04
# tensor([[ 0.2960],
#         [ 2.6552],
#         [-1.7310],
#         [-1.6385],
#         [-0.5837],
#         [-1.5336]], requires_grad=True)
# tensor([[ 0.0164],
#         [-0.0581],
#         [ 0.1410],
#         [-0.0788],
#         [ 0.0352],
#         [-0.0725]], requires_grad=True)
# tensor([[ 0.0071],
#         [-0.3017],
#         [ 0.5231],
#         [-0.0779],
#         [ 0.2362],
#         [-0.3218]], requires_grad=True)
# tensor([[ 0.4184],
#         [-1.8403],
#         [ 1.5681],
#         [-0.8853],
#         [-0.2549],
#         [ 0.3899]], requires_grad=True)
# tensor([[-0.0465],
#         [ 1.5324],
#         [-0.9529],
#         [ 0.1387],
#         [ 0.9420],
#         [ 0.2148]], requires_grad=True)
# tensor([[ 0.2426],
#         [-1.7235],
#         [ 1.1096],
#         [-0.8219],
#         [-1.3207],
#         [ 0.4193]], requires_grad=True)
# tensor([[ 0.5850],
#         [-2.0519],
#         [ 1.5168],
#         [-1.2796],
#         [-0.4923],
#         [ 1.1567]], requires_grad=True)
# tensor([[-0.1539],
#         [-1.1011],
#         [ 1.5110],
#         [ 0.8011],
#         [-0.4847],
#         [-1.1193]], requires_grad=True)
# tensor([[-0.2156],
#         [-2.4409],
#         [ 2.3902],
#         [-0.4027],
#         [-2.2788],
#         [-1.4638]], requires_grad=True)
# tensor([[-0.0636],
#         [-0.0375],
#         [ 0.9118],
#         [ 0.3529],
#         [-2.1681],
#         [ 0.2403]], requires_grad=True)
# tensor([[ 0.0248],
#         [-0.4160],
#         [ 0.3954],
#         [-0.1800],
#         [ 0.3873],
#         [ 0.1372]], requires_grad=True)
# tensor([[ 0.0124],
#         [-0.0288],
#         [ 0.1443],
#         [-0.0552],
#         [-0.0130],
#         [ 0.0160]], requires_grad=True)
# tensor([[ 0.0099],
#         [-0.5444],
#         [ 0.5334],
#         [-0.0913],
#         [ 0.7862],
#         [-0.2511]], requires_grad=True)
# tensor([[ 0.0115],
#         [ 0.0214],
#         [ 0.0851],
#         [-0.0457],
#         [-0.1424],
#         [ 0.2013]], requires_grad=True)
# tensor([[-0.2298],
#         [-0.8703],
#         [ 1.5614],
#         [ 1.2069],
#         [-1.3619],
#         [-0.6910]], requires_grad=True)
# 4500 8.4E-03 5.8E-03 2.2E-03 3.0E-04
# tensor([[ 0.2881],
#         [ 2.5890],
#         [-1.6863],
#         [-1.6065],
#         [-0.4871],
#         [-1.5315]], requires_grad=True)
# tensor([[ 0.0166],
#         [ 0.0071],
#         [ 0.1087],
#         [-0.0857],
#         [-0.1113],
#         [-0.0270]], requires_grad=True)
# tensor([[ 0.0061],
#         [-0.2953],
#         [ 0.5076],
#         [-0.0752],
#         [ 0.2675],
#         [-0.2947]], requires_grad=True)
# tensor([[ 0.4121],
#         [-1.8369],
#         [ 1.5751],
#         [-0.8602],
#         [-0.2096],
#         [ 0.3769]], requires_grad=True)
# tensor([[-2.3562e-02],
#         [ 1.5078e+00],
#         [-9.1734e-01],
#         [ 2.3950e-02],
#         [ 8.9671e-01],
#         [ 6.0616e-04]], requires_grad=True)
# tensor([[ 0.2623],
#         [-1.6637],
#         [ 1.1572],
#         [-0.7537],
#         [-1.2575],
#         [ 0.4310]], requires_grad=True)
# tensor([[ 0.5752],
#         [-2.0552],
#         [ 1.5519],
#         [-1.2537],
#         [-0.4506],
#         [ 1.1004]], requires_grad=True)
# tensor([[-0.1404],
#         [-1.0438],
#         [ 1.4365],
#         [ 0.7296],
#         [-0.3796],
#         [-1.0921]], requires_grad=True)
# tensor([[-0.1309],
#         [-2.4641],
#         [ 2.3925],
#         [-0.3285],
#         [-2.3023],
#         [-1.4777]], requires_grad=True)
# tensor([[-0.0571],
#         [-0.1051],
#         [ 0.8667],
#         [ 0.3106],
#         [-2.0772],
#         [ 0.3391]], requires_grad=True)
# tensor([[ 0.0198],
#         [-0.3657],
#         [ 0.3930],
#         [-0.1555],
#         [ 0.3710],
#         [ 0.0888]], requires_grad=True)
# tensor([[ 0.0133],
#         [-0.0079],
#         [ 0.1388],
#         [-0.0625],
#         [-0.0499],
#         [ 0.0131]], requires_grad=True)
# tensor([[ 0.0073],
#         [-0.4860],
#         [ 0.5218],
#         [-0.0824],
#         [ 0.7505],
#         [-0.2793]], requires_grad=True)
# tensor([[ 0.0169],
#         [ 0.0184],
#         [ 0.0457],
#         [-0.0694],
#         [-0.1034],
#         [ 0.2216]], requires_grad=True)
# tensor([[-0.2267],
#         [-0.8784],
#         [ 1.6035],
#         [ 1.1996],
#         [-1.3598],
#         [-0.6788]], requires_grad=True)
# 5000 5.6E-03 4.5E-03 8.9E-04 2.8E-04
# tensor([[ 0.2793],
#         [ 2.5381],
#         [-1.6412],
#         [-1.5760],
#         [-0.3662],
#         [-1.5166]], requires_grad=True)
# tensor([[ 0.0173],
#         [ 0.0288],
#         [ 0.0824],
#         [-0.0892],
#         [-0.1581],
#         [ 0.0152]], requires_grad=True)
# tensor([[ 0.0058],
#         [-0.2931],
#         [ 0.4880],
#         [-0.0774],
#         [ 0.2557],
#         [-0.2556]], requires_grad=True)
# tensor([[ 0.4072],
#         [-1.8201],
#         [ 1.6101],
#         [-0.8354],
#         [-0.1704],
#         [ 0.3889]], requires_grad=True)
# tensor([[-0.0018],
#         [ 1.4906],
#         [-0.8468],
#         [-0.0847],
#         [ 0.7987],
#         [-0.2303]], requires_grad=True)
# tensor([[ 0.2726],
#         [-1.6317],
#         [ 1.2148],
#         [-0.6980],
#         [-1.2079],
#         [ 0.4587]], requires_grad=True)
# tensor([[ 0.5669],
#         [-2.0404],
#         [ 1.6007],
#         [-1.2300],
#         [-0.4092],
#         [ 1.0696]], requires_grad=True)
# tensor([[-0.1281],
#         [-1.0127],
#         [ 1.3708],
#         [ 0.6652],
#         [-0.3303],
#         [-1.0442]], requires_grad=True)
# tensor([[-0.0632],
#         [-2.4631],
#         [ 2.4169],
#         [-0.2697],
#         [-2.2854],
#         [-1.4212]], requires_grad=True)
# tensor([[-0.0512],
#         [-0.1596],
#         [ 0.8083],
#         [ 0.2734],
#         [-1.9635],
#         [ 0.4588]], requires_grad=True)
# tensor([[ 0.0167],
#         [-0.3391],
#         [ 0.3977],
#         [-0.1414],
#         [ 0.3319],
#         [ 0.0394]], requires_grad=True)
# tensor([[ 0.0143],
#         [-0.0105],
#         [ 0.1321],
#         [-0.0670],
#         [-0.0346],
#         [ 0.0103]], requires_grad=True)
# tensor([[ 0.0062],
#         [-0.4485],
#         [ 0.5030],
#         [-0.0803],
#         [ 0.6877],
#         [-0.2686]], requires_grad=True)
# tensor([[ 0.0180],
#         [ 0.0187],
#         [ 0.0290],
#         [-0.0754],
#         [-0.0983],
#         [ 0.2260]], requires_grad=True)
# tensor([[-0.2228],
#         [-0.9023],
#         [ 1.6527],
#         [ 1.1917],
#         [-1.3663],
#         [-0.6678]], requires_grad=True)
# 5500 5.0E-03 3.9E-03 8.1E-04 2.7E-04
# tensor([[ 0.2657],
#         [ 2.3567],
#         [-1.5512],
#         [-1.5061],
#         [-0.3407],
#         [-1.4890]], requires_grad=True)
# tensor([[ 0.0192],
#         [ 0.0412],
#         [ 0.0505],
#         [-0.1013],
#         [-0.1946],
#         [ 0.0478]], requires_grad=True)
# tensor([[ 0.0075],
#         [-0.2209],
#         [ 0.4441],
#         [-0.0860],
#         [ 0.3100],
#         [-0.2792]], requires_grad=True)
# tensor([[ 0.3937],
#         [-1.7645],
#         [ 1.5563],
#         [-0.7857],
#         [-0.0981],
#         [ 0.3236]], requires_grad=True)
# tensor([[ 0.0156],
#         [ 1.3430],
#         [-0.7608],
#         [-0.1877],
#         [ 0.6809],
#         [-0.3415]], requires_grad=True)
# tensor([[ 0.2705],
#         [-1.5404],
#         [ 1.1740],
#         [-0.6261],
#         [-1.0053],
#         [ 0.3844]], requires_grad=True)
# tensor([[ 0.5503],
#         [-2.0040],
#         [ 1.5861],
#         [-1.1742],
#         [-0.3580],
#         [ 0.9581]], requires_grad=True)
# tensor([[-0.1111],
#         [-0.8309],
#         [ 1.2620],
#         [ 0.5742],
#         [-0.2317],
#         [-1.0464]], requires_grad=True)
# tensor([[ 6.8021e-04],
#         [-2.3403e+00],
#         [ 2.3275e+00],
#         [-2.1965e-01],
#         [-2.0737e+00],
#         [-1.4861e+00]], requires_grad=True)
# tensor([[-0.0433],
#         [-0.1290],
#         [ 0.7485],
#         [ 0.2291],
#         [-1.7555],
#         [ 0.4531]], requires_grad=True)
# tensor([[ 0.0158],
#         [-0.2512],
#         [ 0.3773],
#         [-0.1341],
#         [ 0.3674],
#         [-0.0540]], requires_grad=True)
# tensor([[ 0.0163],
#         [ 0.0082],
#         [ 0.1058],
#         [-0.0793],
#         [-0.0900],
#         [ 0.0266]], requires_grad=True)
# tensor([[ 0.0070],
#         [-0.3347],
#         [ 0.4574],
#         [-0.0857],
#         [ 0.6683],
#         [-0.3217]], requires_grad=True)
# tensor([[ 0.0210],
#         [ 0.0275],
#         [ 0.0089],
#         [-0.0941],
#         [-0.1303],
#         [ 0.1961]], requires_grad=True)
# tensor([[-0.2200],
#         [-0.9026],
#         [ 1.6939],
#         [ 1.1783],
#         [-1.3536],
#         [-0.6538]], requires_grad=True)
# 6000 4.2E-03 3.3E-03 6.4E-04 2.5E-04
# tensor([[ 0.2552],
#         [ 2.3274],
#         [-1.5469],
#         [-1.4714],
#         [-0.2763],
#         [-1.4802]], requires_grad=True)
# tensor([[ 0.0186],
#         [ 0.0473],
#         [ 0.0445],
#         [-0.0965],
#         [-0.2006],
#         [ 0.0820]], requires_grad=True)
# tensor([[ 0.0075],
#         [-0.2370],
#         [ 0.4577],
#         [-0.0878],
#         [ 0.2470],
#         [-0.2432]], requires_grad=True)
# tensor([[ 0.3841],
#         [-1.7435],
#         [ 1.5997],
#         [-0.7577],
#         [-0.0467],
#         [ 0.3529]], requires_grad=True)
# tensor([[ 0.0286],
#         [ 1.3427],
#         [-0.7544],
#         [-0.2468],
#         [ 0.6570],
#         [-0.4278]], requires_grad=True)
# tensor([[ 0.2661],
#         [-1.5353],
#         [ 1.2295],
#         [-0.5885],
#         [-0.9347],
#         [ 0.4142]], requires_grad=True)
# tensor([[ 0.5428],
#         [-1.9653],
#         [ 1.6378],
#         [-1.1412],
#         [-0.3080],
#         [ 0.9472]], requires_grad=True)
# tensor([[-0.1011],
#         [-0.8039],
#         [ 1.2455],
#         [ 0.5254],
#         [-0.2470],
#         [-1.0355]], requires_grad=True)
# tensor([[ 0.0305],
#         [-2.2706],
#         [ 2.3809],
#         [-0.2046],
#         [-1.9605],
#         [-1.4074]], requires_grad=True)
# tensor([[-0.0376],
#         [-0.1530],
#         [ 0.7230],
#         [ 0.1952],
#         [-1.6324],
#         [ 0.4999]], requires_grad=True)
# tensor([[ 0.0140],
#         [-0.2588],
#         [ 0.4046],
#         [-0.1266],
#         [ 0.2798],
#         [-0.0591]], requires_grad=True)
# tensor([[ 0.0162],
#         [-0.0023],
#         [ 0.1032],
#         [-0.0771],
#         [-0.0514],
#         [ 0.0407]], requires_grad=True)
# tensor([[ 0.0069],
#         [-0.3349],
#         [ 0.4676],
#         [-0.0874],
#         [ 0.5480],
#         [-0.2784]], requires_grad=True)
# tensor([[ 0.0201],
#         [ 0.0296],
#         [ 0.0101],
#         [-0.0888],
#         [-0.1210],
#         [ 0.2114]], requires_grad=True)
# tensor([[-0.2148],
#         [-0.9240],
#         [ 1.7540],
#         [ 1.1687],
#         [-1.3594],
#         [-0.6393]], requires_grad=True)
# 6500 3.6E-03 2.8E-03 5.6E-04 2.4E-04
# tensor([[ 0.2458],
#         [ 2.2950],
#         [-1.5278],
#         [-1.4318],
#         [-0.2355],
#         [-1.4716]], requires_grad=True)
# tensor([[ 0.0178],
#         [ 0.0474],
#         [ 0.0430],
#         [-0.0918],
#         [-0.1996],
#         [ 0.1025]], requires_grad=True)
# tensor([[ 0.0092],
#         [-0.2138],
#         [ 0.4456],
#         [-0.0971],
#         [ 0.1954],
#         [-0.2078]], requires_grad=True)
# tensor([[ 3.7325e-01],
#         [-1.7185e+00],
#         [ 1.6412e+00],
#         [-7.2489e-01],
#         [ 2.8861e-04],
#         [ 3.8106e-01]], requires_grad=True)
# tensor([[ 0.0381],
#         [ 1.3596],
#         [-0.7327],
#         [-0.2904],
#         [ 0.6206],
#         [-0.5438]], requires_grad=True)
# tensor([[ 0.2612],
#         [-1.5255],
#         [ 1.2872],
#         [-0.5501],
#         [-0.8401],
#         [ 0.4330]], requires_grad=True)
# tensor([[ 0.5290],
#         [-1.9349],
#         [ 1.6828],
#         [-1.1100],
#         [-0.2579],
#         [ 0.9414]], requires_grad=True)
# tensor([[-0.0925],
#         [-0.7481],
#         [ 1.2130],
#         [ 0.4807],
#         [-0.2743],
#         [-1.0328]], requires_grad=True)
# tensor([[ 0.0568],
#         [-2.2012],
#         [ 2.4160],
#         [-0.1889],
#         [-1.8379],
#         [-1.3425]], requires_grad=True)
# tensor([[-0.0316],
#         [-0.1607],
#         [ 0.6827],
#         [ 0.1605],
#         [-1.4892],
#         [ 0.5467]], requires_grad=True)
# tensor([[ 0.0143],
#         [-0.2320],
#         [ 0.4071],
#         [-0.1277],
#         [ 0.2233],
#         [-0.0664]], requires_grad=True)
# tensor([[ 0.0162],
#         [-0.0117],
#         [ 0.0987],
#         [-0.0747],
#         [-0.0241],
#         [ 0.0633]], requires_grad=True)
# tensor([[ 0.0085],
#         [-0.2974],
#         [ 0.4542],
#         [-0.0953],
#         [ 0.4436],
#         [-0.2373]], requires_grad=True)
# tensor([[ 0.0195],
#         [ 0.0302],
#         [ 0.0139],
#         [-0.0849],
#         [-0.1289],
#         [ 0.2161]], requires_grad=True)
# tensor([[-0.2109],
#         [-0.9507],
#         [ 1.8018],
#         [ 1.1590],
#         [-1.3755],
#         [-0.6356]], requires_grad=True)
# 7000 3.9E-03 2.6E-03 1.0E-03 2.2E-04
# tensor([[ 0.2358],
#         [ 2.2228],
#         [-1.5136],
#         [-1.3891],
#         [-0.2343],
#         [-1.4686]], requires_grad=True)
# tensor([[ 0.0174],
#         [ 0.0423],
#         [ 0.0413],
#         [-0.0868],
#         [-0.1830],
#         [ 0.1247]], requires_grad=True)
# tensor([[ 0.0106],
#         [-0.1798],
#         [ 0.4336],
#         [-0.1021],
#         [ 0.1493],
#         [-0.1707]], requires_grad=True)
# tensor([[ 0.3615],
#         [-1.6864],
#         [ 1.6785],
#         [-0.6833],
#         [ 0.0545],
#         [ 0.4066]], requires_grad=True)
# tensor([[ 0.0430],
#         [ 1.3568],
#         [-0.7254],
#         [-0.3210],
#         [ 0.5938],
#         [-0.6527]], requires_grad=True)
# tensor([[ 0.2542],
#         [-1.5072],
#         [ 1.3434],
#         [-0.5066],
#         [-0.7166],
#         [ 0.4391]], requires_grad=True)
# tensor([[ 0.5151],
#         [-1.8973],
#         [ 1.7240],
#         [-1.0695],
#         [-0.1981],
#         [ 0.9291]], requires_grad=True)
# tensor([[-0.0841],
#         [-0.6619],
#         [ 1.1764],
#         [ 0.4367],
#         [-0.3304],
#         [-1.0359]], requires_grad=True)
# tensor([[ 0.0798],
#         [-2.1225],
#         [ 2.4470],
#         [-0.1724],
#         [-1.6992],
#         [-1.2802]], requires_grad=True)
# tensor([[-0.0257],
#         [-0.1493],
#         [ 0.6410],
#         [ 0.1276],
#         [-1.3032],
#         [ 0.5785]], requires_grad=True)
# tensor([[ 0.0149],
#         [-0.1925],
#         [ 0.4022],
#         [-0.1291],
#         [ 0.1829],
#         [-0.0636]], requires_grad=True)
# tensor([[ 0.0163],
#         [-0.0195],
#         [ 0.0919],
#         [-0.0714],
#         [ 0.0013],
#         [ 0.0934]], requires_grad=True)
# tensor([[ 0.0100],
#         [-0.2427],
#         [ 0.4375],
#         [-0.1012],
#         [ 0.3402],
#         [-0.1996]], requires_grad=True)
# tensor([[ 0.0190],
#         [ 0.0259],
#         [ 0.0188],
#         [-0.0811],
#         [-0.1233],
#         [ 0.2188]], requires_grad=True)
# tensor([[-0.2070],
#         [-0.9684],
#         [ 1.8419],
#         [ 1.1494],
#         [-1.3900],
#         [-0.6298]], requires_grad=True)
# 7500 3.4E-03 2.3E-03 9.1E-04 2.0E-04
# tensor([[ 0.2261],
#         [ 2.1228],
#         [-1.4920],
#         [-1.3462],
#         [-0.2445],
#         [-1.4641]], requires_grad=True)
# tensor([[ 0.0169],
#         [ 0.0375],
#         [ 0.0417],
#         [-0.0821],
#         [-0.1656],
#         [ 0.1402]], requires_grad=True)
# tensor([[ 0.0108],
#         [-0.1499],
#         [ 0.4293],
#         [-0.1009],
#         [ 0.1069],
#         [-0.1420]], requires_grad=True)
# tensor([[ 0.3464],
#         [-1.6354],
#         [ 1.7106],
#         [-0.6356],
#         [ 0.1179],
#         [ 0.4224]], requires_grad=True)
# tensor([[ 0.0461],
#         [ 1.3444],
#         [-0.7337],
#         [-0.3400],
#         [ 0.5833],
#         [-0.7420]], requires_grad=True)
# tensor([[ 0.2437],
#         [-1.4708],
#         [ 1.3907],
#         [-0.4600],
#         [-0.5701],
#         [ 0.4304]], requires_grad=True)
# tensor([[ 0.4989],
#         [-1.8446],
#         [ 1.7594],
#         [-1.0204],
#         [-0.1148],
#         [ 0.9122]], requires_grad=True)
# tensor([[-0.0757],
#         [-0.5697],
#         [ 1.1371],
#         [ 0.3951],
#         [-0.4060],
#         [-1.0262]], requires_grad=True)
# tensor([[ 0.0971],
#         [-2.0313],
#         [ 2.4731],
#         [-0.1574],
#         [-1.5452],
#         [-1.2273]], requires_grad=True)
# tensor([[-0.0199],
#         [-0.1330],
#         [ 0.6012],
#         [ 0.0958],
#         [-1.0998],
#         [ 0.5808]], requires_grad=True)
# tensor([[ 0.0150],
#         [-0.1563],
#         [ 0.4002],
#         [-0.1267],
#         [ 0.1472],
#         [-0.0601]], requires_grad=True)
# tensor([[ 0.0161],
#         [-0.0241],
#         [ 0.0873],
#         [-0.0677],
#         [ 0.0205],
#         [ 0.1151]], requires_grad=True)
# tensor([[ 0.0107],
#         [-0.1915],
#         [ 0.4272],
#         [-0.1018],
#         [ 0.2418],
#         [-0.1712]], requires_grad=True)
# tensor([[ 0.0185],
#         [ 0.0209],
#         [ 0.0222],
#         [-0.0779],
#         [-0.1125],
#         [ 0.2201]], requires_grad=True)
# tensor([[-0.2033],
#         [-0.9687],
#         [ 1.8740],
#         [ 1.1400],
#         [-1.3961],
#         [-0.6199]], requires_grad=True)
# 8000 2.5E-03 2.0E-03 3.8E-04 1.8E-04
# tensor([[ 0.2180],
#         [ 2.0195],
#         [-1.4634],
#         [-1.3046],
#         [-0.2451],
#         [-1.4569]], requires_grad=True)
# tensor([[ 0.0162],
#         [ 0.0339],
#         [ 0.0443],
#         [-0.0772],
#         [-0.1541],
#         [ 0.1473]], requires_grad=True)
# tensor([[ 0.0104],
#         [-0.1286],
#         [ 0.4271],
#         [-0.0963],
#         [ 0.0765],
#         [-0.1144]], requires_grad=True)
# tensor([[ 0.3308],
#         [-1.5723],
#         [ 1.7373],
#         [-0.5878],
#         [ 0.1896],
#         [ 0.4335]], requires_grad=True)
# tensor([[ 0.0485],
#         [ 1.3244],
#         [-0.7498],
#         [-0.3524],
#         [ 0.5730],
#         [-0.8075]], requires_grad=True)
# tensor([[ 0.2315],
#         [-1.4167],
#         [ 1.4281],
#         [-0.4127],
#         [-0.4060],
#         [ 0.4163]], requires_grad=True)
# tensor([[ 0.4815],
#         [-1.7808],
#         [ 1.7888],
#         [-0.9683],
#         [-0.0055],
#         [ 0.8985]], requires_grad=True)
# tensor([[-0.0682],
#         [-0.4843],
#         [ 1.0937],
#         [ 0.3577],
#         [-0.4907],
#         [-0.9962]], requires_grad=True)
# tensor([[ 0.1105],
#         [-1.9247],
#         [ 2.4916],
#         [-0.1426],
#         [-1.3672],
#         [-1.1863]], requires_grad=True)
# tensor([[-0.0145],
#         [-0.1180],
#         [ 0.5628],
#         [ 0.0663],
#         [-0.8970],
#         [ 0.5480]], requires_grad=True)
# tensor([[ 0.0144],
#         [-0.1298],
#         [ 0.3985],
#         [-0.1215],
#         [ 0.1225],
#         [-0.0512]], requires_grad=True)
# tensor([[ 0.0155],
#         [-0.0262],
#         [ 0.0857],
#         [-0.0639],
#         [ 0.0281],
#         [ 0.1275]], requires_grad=True)
# tensor([[ 0.0105],
#         [-0.1524],
#         [ 0.4204],
#         [-0.0981],
#         [ 0.1601],
#         [-0.1434]], requires_grad=True)
# tensor([[ 0.0177],
#         [ 0.0193],
#         [ 0.0243],
#         [-0.0741],
#         [-0.1107],
#         [ 0.2201]], requires_grad=True)
# tensor([[-0.1998],
#         [-0.9498],
#         [ 1.8964],
#         [ 1.1304],
#         [-1.3947],
#         [-0.6125]], requires_grad=True)
# 8500 2.1E-03 1.7E-03 2.9E-04 1.6E-04
# tensor([[ 0.2088],
#         [ 1.9096],
#         [-1.4420],
#         [-1.2657],
#         [-0.2501],
#         [-1.4515]], requires_grad=True)
# tensor([[ 0.0154],
#         [ 0.0303],
#         [ 0.0478],
#         [-0.0725],
#         [-0.1470],
#         [ 0.1458]], requires_grad=True)
# tensor([[ 0.0097],
#         [-0.1141],
#         [ 0.4317],
#         [-0.0904],
#         [ 0.0591],
#         [-0.0848]], requires_grad=True)
# tensor([[ 0.3153],
#         [-1.4985],
#         [ 1.7617],
#         [-0.5387],
#         [ 0.2674],
#         [ 0.4392]], requires_grad=True)
# tensor([[ 0.0485],
#         [ 1.2876],
#         [-0.7678],
#         [-0.3633],
#         [ 0.5501],
#         [-0.8420]], requires_grad=True)
# tensor([[ 0.2181],
#         [-1.3451],
#         [ 1.4576],
#         [-0.3631],
#         [-0.2356],
#         [ 0.3995]], requires_grad=True)
# tensor([[ 0.4648],
#         [-1.7023],
#         [ 1.8136],
#         [-0.9104],
#         [ 0.1233],
#         [ 0.8841]], requires_grad=True)
# tensor([[-0.0618],
#         [-0.4110],
#         [ 1.0586],
#         [ 0.3262],
#         [-0.5714],
#         [-0.9487]], requires_grad=True)
# tensor([[ 0.1194],
#         [-1.8019],
#         [ 2.5044],
#         [-0.1271],
#         [-1.1614],
#         [-1.1510]], requires_grad=True)
# tensor([[-0.0103],
#         [-0.1041],
#         [ 0.5364],
#         [ 0.0412],
#         [-0.7015],
#         [ 0.4785]], requires_grad=True)
# tensor([[ 0.0137],
#         [-0.1128],
#         [ 0.4031],
#         [-0.1149],
#         [ 0.1106],
#         [-0.0356]], requires_grad=True)
# tensor([[ 0.0149],
#         [-0.0270],
#         [ 0.0859],
#         [-0.0594],
#         [ 0.0273],
#         [ 0.1304]], requires_grad=True)
# tensor([[ 0.0099],
#         [-0.1252],
#         [ 0.4225],
#         [-0.0923],
#         [ 0.0992],
#         [-0.1117]], requires_grad=True)
# tensor([[ 0.0169],
#         [ 0.0200],
#         [ 0.0250],
#         [-0.0711],
#         [-0.1162],
#         [ 0.2159]], requires_grad=True)
# tensor([[-0.1963],
#         [-0.9155],
#         [ 1.9090],
#         [ 1.1202],
#         [-1.3900],
#         [-0.6156]], requires_grad=True)
# 9000 2.7E-03 1.8E-03 8.3E-04 1.5E-04
# tensor([[ 0.2029],
#         [ 1.8245],
#         [-1.4207],
#         [-1.2327],
#         [-0.2492],
#         [-1.4465]], requires_grad=True)
# tensor([[ 0.0143],
#         [ 0.0284],
#         [ 0.0540],
#         [-0.0677],
#         [-0.1478],
#         [ 0.1366]], requires_grad=True)
# tensor([[ 0.0084],
#         [-0.1025],
#         [ 0.4324],
#         [-0.0827],
#         [ 0.0481],
#         [-0.0562]], requires_grad=True)
# tensor([[ 0.3000],
#         [-1.4161],
#         [ 1.7840],
#         [-0.4931],
#         [ 0.3531],
#         [ 0.4420]], requires_grad=True)
# tensor([[ 0.0500],
#         [ 1.2590],
#         [-0.7822],
#         [-0.3696],
#         [ 0.5187],
#         [-0.8621]], requires_grad=True)
# tensor([[ 0.2042],
#         [-1.2612],
#         [ 1.4792],
#         [-0.3157],
#         [-0.0665],
#         [ 0.3800]], requires_grad=True)
# tensor([[ 0.4456],
#         [-1.6142],
#         [ 1.8371],
#         [-0.8523],
#         [ 0.2677],
#         [ 0.8723]], requires_grad=True)
# tensor([[-0.0569],
#         [-0.3516],
#         [ 1.0245],
#         [ 0.3032],
#         [-0.6336],
#         [-0.8995]], requires_grad=True)
# tensor([[ 0.1250],
#         [-1.6681],
#         [ 2.5046],
#         [-0.1100],
#         [-0.9311],
#         [-1.1242]], requires_grad=True)
# tensor([[-0.0074],
#         [-0.0956],
#         [ 0.5143],
#         [ 0.0227],
#         [-0.5254],
#         [ 0.3790]], requires_grad=True)
# tensor([[ 0.0123],
#         [-0.0995],
#         [ 0.4036],
#         [-0.1068],
#         [ 0.1048],
#         [-0.0186]], requires_grad=True)
# tensor([[ 0.0138],
#         [-0.0254],
#         [ 0.0887],
#         [-0.0553],
#         [ 0.0161],
#         [ 0.1262]], requires_grad=True)
# tensor([[ 0.0085],
#         [-0.1053],
#         [ 0.4235],
#         [-0.0836],
#         [ 0.0527],
#         [-0.0775]], requires_grad=True)
# tensor([[ 0.0158],
#         [ 0.0219],
#         [ 0.0276],
#         [-0.0676],
#         [-0.1291],
#         [ 0.2057]], requires_grad=True)
# tensor([[-0.1932],
#         [-0.8691],
#         [ 1.9116],
#         [ 1.1092],
#         [-1.3854],
#         [-0.6356]], requires_grad=True)
# 9500 1.6E-03 1.2E-03 1.9E-04 1.4E-04
# tensor([[ 0.1970],
#         [ 1.7502],
#         [-1.4051],
#         [-1.2049],
#         [-0.2537],
#         [-1.4424]], requires_grad=True)
# tensor([[ 0.0132],
#         [ 0.0240],
#         [ 0.0621],
#         [-0.0634],
#         [-0.1489],
#         [ 0.1250]], requires_grad=True)
# tensor([[ 0.0074],
#         [-0.0953],
#         [ 0.4337],
#         [-0.0752],
#         [ 0.0457],
#         [-0.0261]], requires_grad=True)
# tensor([[ 0.2868],
#         [-1.3317],
#         [ 1.8043],
#         [-0.4494],
#         [ 0.4470],
#         [ 0.4425]], requires_grad=True)
# tensor([[ 0.0495],
#         [ 1.2198],
#         [-0.7911],
#         [-0.3770],
#         [ 0.4800],
#         [-0.8681]], requires_grad=True)
# tensor([[ 0.1912],
#         [-1.1687],
#         [ 1.4948],
#         [-0.2694],
#         [ 0.0897],
#         [ 0.3587]], requires_grad=True)
# tensor([[ 0.4268],
#         [-1.5200],
#         [ 1.8579],
#         [-0.7933],
#         [ 0.4150],
#         [ 0.8598]], requires_grad=True)
# tensor([[-0.0537],
#         [-0.3041],
#         [ 0.9991],
#         [ 0.2877],
#         [-0.6889],
#         [-0.8625]], requires_grad=True)
# tensor([[ 0.1283],
#         [-1.5242],
#         [ 2.4950],
#         [-0.0901],
#         [-0.6896],
#         [-1.1003]], requires_grad=True)
# tensor([[-0.0054],
#         [-0.0906],
#         [ 0.5032],
#         [ 0.0090],
#         [-0.3684],
#         [ 0.2678]], requires_grad=True)
# tensor([[ 0.0113],
#         [-0.0919],
#         [ 0.4049],
#         [-0.0985],
#         [ 0.1070],
#         [ 0.0033]], requires_grad=True)
# tensor([[ 0.0129],
#         [-0.0255],
#         [ 0.0934],
#         [-0.0515],
#         [ 0.0011],
#         [ 0.1196]], requires_grad=True)
# tensor([[ 0.0072],
#         [-0.0937],
#         [ 0.4268],
#         [-0.0741],
#         [ 0.0237],
#         [-0.0392]], requires_grad=True)
# tensor([[ 0.0147],
#         [ 0.0218],
#         [ 0.0342],
#         [-0.0646],
#         [-0.1405],
#         [ 0.1893]], requires_grad=True)
# tensor([[-0.1901],
#         [-0.8194],
#         [ 1.9038],
#         [ 1.0968],
#         [-1.3849],
#         [-0.6786]], requires_grad=True)
# 10000 1.3E-03 1.0E-03 1.6E-04 1.3E-04
# tensor([[ 0.1932],
#         [ 1.6876],
#         [-1.3911],
#         [-1.1832],
#         [-0.2608],
#         [-1.4376]], requires_grad=True)
# tensor([[ 0.0123],
#         [ 0.0169],
#         [ 0.0718],
#         [-0.0593],
#         [-0.1421],
#         [ 0.1121]], requires_grad=True)
# tensor([[ 0.0060],
#         [-0.0963],
#         [ 0.4422],
#         [-0.0651],
#         [ 0.0465],
#         [ 0.0009]], requires_grad=True)
# tensor([[ 0.2727],
#         [-1.2441],
#         [ 1.8244],
#         [-0.4059],
#         [ 0.5404],
#         [ 0.4373]], requires_grad=True)
# tensor([[ 0.0501],
#         [ 1.1880],
#         [-0.7959],
#         [-0.3812],
#         [ 0.4567],
#         [-0.8694]], requires_grad=True)
# tensor([[ 0.1771],
#         [-1.0758],
#         [ 1.5061],
#         [-0.2249],
#         [ 0.2152],
#         [ 0.3358]], requires_grad=True)
# tensor([[ 0.4059],
#         [-1.4235],
#         [ 1.8765],
#         [-0.7337],
#         [ 0.5489],
#         [ 0.8453]], requires_grad=True)
# tensor([[-0.0510],
#         [-0.2720],
#         [ 0.9825],
#         [ 0.2762],
#         [-0.7205],
#         [-0.8411]], requires_grad=True)
# tensor([[ 0.1277],
#         [-1.3864],
#         [ 2.4842],
#         [-0.0668],
#         [-0.4731],
#         [-1.0742]], requires_grad=True)
# tensor([[-0.0043],
#         [-0.0931],
#         [ 0.5033],
#         [ 0.0016],
#         [-0.2520],
#         [ 0.1738]], requires_grad=True)
# tensor([[ 0.0097],
#         [-0.0934],
#         [ 0.4137],
#         [-0.0876],
#         [ 0.1105],
#         [ 0.0256]], requires_grad=True)
# tensor([[ 0.0121],
#         [-0.0280],
#         [ 0.0990],
#         [-0.0481],
#         [-0.0066],
#         [ 0.1117]], requires_grad=True)
# tensor([[ 0.0055],
#         [-0.0927],
#         [ 0.4378],
#         [-0.0621],
#         [ 0.0075],
#         [-0.0035]], requires_grad=True)
# tensor([[ 0.0137],
#         [ 0.0173],
#         [ 0.0451],
#         [-0.0611],
#         [-0.1414],
#         [ 0.1683]], requires_grad=True)
# tensor([[-0.1865],
#         [-0.7756],
#         [ 1.8973],
#         [ 1.0823],
#         [-1.3855],
#         [-0.7386]], requires_grad=True)
# 10500 1.9E-03 1.1E-03 6.7E-04 1.2E-04
# tensor([[ 0.1904],
#         [ 1.6313],
#         [-1.3802],
#         [-1.1651],
#         [-0.2698],
#         [-1.4344]], requires_grad=True)
# tensor([[ 0.0116],
#         [ 0.0083],
#         [ 0.0790],
#         [-0.0556],
#         [-0.1342],
#         [ 0.1057]], requires_grad=True)
# tensor([[ 0.0048],
#         [-0.0977],
#         [ 0.4486],
#         [-0.0578],
#         [ 0.0464],
#         [ 0.0255]], requires_grad=True)
# tensor([[ 0.2625],
#         [-1.1590],
#         [ 1.8399],
#         [-0.3709],
#         [ 0.6449],
#         [ 0.4318]], requires_grad=True)
# tensor([[ 0.0512],
#         [ 1.1472],
#         [-0.7954],
#         [-0.3885],
#         [ 0.4330],
#         [-0.8704]], requires_grad=True)
# tensor([[ 0.1657],
#         [-0.9755],
#         [ 1.5115],
#         [-0.1869],
#         [ 0.3326],
#         [ 0.3165]], requires_grad=True)
# tensor([[ 0.3881],
#         [-1.3231],
#         [ 1.8918],
#         [-0.6812],
#         [ 0.6781],
#         [ 0.8336]], requires_grad=True)
# tensor([[-0.0483],
#         [-0.2479],
#         [ 0.9739],
#         [ 0.2636],
#         [-0.7399],
#         [-0.8457]], requires_grad=True)
# tensor([[ 0.1265],
#         [-1.2409],
#         [ 2.4606],
#         [-0.0421],
#         [-0.2535],
#         [-1.0507]], requires_grad=True)
# tensor([[-0.0034],
#         [-0.0951],
#         [ 0.5023],
#         [-0.0063],
#         [-0.1708],
#         [ 0.1036]], requires_grad=True)
# tensor([[ 0.0082],
#         [-0.0953],
#         [ 0.4209],
#         [-0.0787],
#         [ 0.1099],
#         [ 0.0490]], requires_grad=True)
# tensor([[ 0.0114],
#         [-0.0321],
#         [ 0.1028],
#         [-0.0453],
#         [-0.0136],
#         [ 0.1085]], requires_grad=True)
# tensor([[ 0.0041],
#         [-0.0937],
#         [ 0.4471],
#         [-0.0533],
#         [-0.0008],
#         [ 0.0296]], requires_grad=True)
# tensor([[ 0.0127],
#         [ 0.0100],
#         [ 0.0550],
#         [-0.0579],
#         [-0.1389],
#         [ 0.1522]], requires_grad=True)
# tensor([[-0.1829],
#         [-0.7326],
#         [ 1.8964],
#         [ 1.0652],
#         [-1.3840],
#         [-0.8107]], requires_grad=True)
# 11000 9.4E-04 7.0E-04 1.2E-04 1.2E-04
# tensor([[ 0.1874],
#         [ 1.5797],
#         [-1.3701],
#         [-1.1492],
#         [-0.2811],
#         [-1.4305]], requires_grad=True)
# tensor([[ 0.0110],
#         [ 0.0007],
#         [ 0.0861],
#         [-0.0518],
#         [-0.1201],
#         [ 0.1015]], requires_grad=True)
# tensor([[ 0.0043],
#         [-0.0925],
#         [ 0.4572],
#         [-0.0516],
#         [ 0.0455],
#         [ 0.0476]], requires_grad=True)
# tensor([[ 0.2531],
#         [-1.0759],
#         [ 1.8535],
#         [-0.3365],
#         [ 0.7486],
#         [ 0.4241]], requires_grad=True)
# tensor([[ 0.0526],
#         [ 1.1037],
#         [-0.7904],
#         [-0.3972],
#         [ 0.4292],
#         [-0.8692]], requires_grad=True)
# tensor([[ 0.1553],
#         [-0.8782],
#         [ 1.5145],
#         [-0.1507],
#         [ 0.4209],
#         [ 0.2981]], requires_grad=True)
# tensor([[ 0.3716],
#         [-1.2221],
#         [ 1.9030],
#         [-0.6280],
#         [ 0.7927],
#         [ 0.8208]], requires_grad=True)
# tensor([[-0.0463],
#         [-0.2226],
#         [ 0.9749],
#         [ 0.2553],
#         [-0.7495],
#         [-0.8503]], requires_grad=True)
# tensor([[ 0.1233],
#         [-1.1010],
#         [ 2.4316],
#         [-0.0153],
#         [-0.0557],
#         [-1.0230]], requires_grad=True)
# tensor([[-0.0021],
#         [-0.0883],
#         [ 0.5036],
#         [-0.0123],
#         [-0.1212],
#         [ 0.0615]], requires_grad=True)
# tensor([[ 0.0073],
#         [-0.0914],
#         [ 0.4313],
#         [-0.0702],
#         [ 0.1055],
#         [ 0.0725]], requires_grad=True)
# tensor([[ 0.0109],
#         [-0.0335],
#         [ 0.1056],
#         [-0.0425],
#         [-0.0145],
#         [ 0.1068]], requires_grad=True)
# tensor([[ 0.0035],
#         [-0.0886],
#         [ 0.4575],
#         [-0.0464],
#         [-0.0032],
#         [ 0.0570]], requires_grad=True)
# tensor([[ 0.0120],
#         [ 0.0026],
#         [ 0.0656],
#         [-0.0543],
#         [-0.1284],
#         [ 0.1389]], requires_grad=True)
# tensor([[-0.1795],
#         [-0.6894],
#         [ 1.9012],
#         [ 1.0468],
#         [-1.3741],
#         [-0.8916]], requires_grad=True)
# 11500 7.8E-04 5.7E-04 1.0E-04 1.1E-04
# tensor([[ 0.1851],
#         [ 1.5367],
#         [-1.3595],
#         [-1.1343],
#         [-0.2928],
#         [-1.4267]], requires_grad=True)
# tensor([[ 0.0105],
#         [-0.0081],
#         [ 0.0920],
#         [-0.0480],
#         [-0.1048],
#         [ 0.1016]], requires_grad=True)
# tensor([[ 0.0034],
#         [-0.0859],
#         [ 0.4624],
#         [-0.0458],
#         [ 0.0384],
#         [ 0.0686]], requires_grad=True)
# tensor([[ 0.2441],
#         [-0.9907],
#         [ 1.8640],
#         [-0.3022],
#         [ 0.8479],
#         [ 0.4123]], requires_grad=True)
# tensor([[ 0.0544],
#         [ 1.0556],
#         [-0.7810],
#         [-0.4065],
#         [ 0.4563],
#         [-0.8671]], requires_grad=True)
# tensor([[ 0.1455],
#         [-0.7842],
#         [ 1.5127],
#         [-0.1167],
#         [ 0.4939],
#         [ 0.2787]], requires_grad=True)
# tensor([[ 0.3548],
#         [-1.1189],
#         [ 1.9089],
#         [-0.5746],
#         [ 0.8991],
#         [ 0.8068]], requires_grad=True)
# tensor([[-0.0445],
#         [-0.1972],
#         [ 0.9688],
#         [ 0.2465],
#         [-0.7581],
#         [-0.8413]], requires_grad=True)
# tensor([[ 0.1181],
#         [-0.9699],
#         [ 2.3923],
#         [ 0.0151],
#         [ 0.1226],
#         [-0.9961]], requires_grad=True)
# tensor([[-0.0011],
#         [-0.0789],
#         [ 0.4985],
#         [-0.0189],
#         [-0.0873],
#         [ 0.0322]], requires_grad=True)
# tensor([[ 0.0059],
#         [-0.0863],
#         [ 0.4398],
#         [-0.0610],
#         [ 0.0907],
#         [ 0.0980]], requires_grad=True)
# tensor([[ 0.0104],
#         [-0.0366],
#         [ 0.1079],
#         [-0.0398],
#         [-0.0141],
#         [ 0.1074]], requires_grad=True)
# tensor([[ 0.0027],
#         [-0.0820],
#         [ 0.4635],
#         [-0.0406],
#         [-0.0059],
#         [ 0.0791]], requires_grad=True)
# tensor([[ 0.0113],
#         [-0.0063],
#         [ 0.0748],
#         [-0.0505],
#         [-0.1149],
#         [ 0.1317]], requires_grad=True)
# tensor([[-0.1765],
#         [-0.6436],
#         [ 1.9033],
#         [ 1.0266],
#         [-1.3520],
#         [-0.9712]], requires_grad=True)
# 12000 6.9E-04 4.7E-04 1.1E-04 1.1E-04
# tensor([[ 0.1828],
#         [ 1.4989],
#         [-1.3480],
#         [-1.1213],
#         [-0.3096],
#         [-1.4215]], requires_grad=True)
# tensor([[ 0.0099],
#         [-0.0150],
#         [ 0.0967],
#         [-0.0437],
#         [-0.0918],
#         [ 0.1049]], requires_grad=True)
# tensor([[ 0.0028],
#         [-0.0772],
#         [ 0.4608],
#         [-0.0422],
#         [ 0.0275],
#         [ 0.0893]], requires_grad=True)
# tensor([[ 0.2358],
#         [-0.9066],
#         [ 1.8735],
#         [-0.2677],
#         [ 0.9422],
#         [ 0.3981]], requires_grad=True)
# tensor([[ 0.0560],
#         [ 1.0049],
#         [-0.7686],
#         [-0.4164],
#         [ 0.4970],
#         [-0.8638]], requires_grad=True)
# tensor([[ 0.1371],
#         [-0.6970],
#         [ 1.5105],
#         [-0.0851],
#         [ 0.5587],
#         [ 0.2597]], requires_grad=True)
# tensor([[ 0.3389],
#         [-1.0147],
#         [ 1.9110],
#         [-0.5213],
#         [ 1.0023],
#         [ 0.7922]], requires_grad=True)
# tensor([[-0.0428],
#         [-0.1734],
#         [ 0.9562],
#         [ 0.2377],
#         [-0.7659],
#         [-0.8173]], requires_grad=True)
# tensor([[ 0.1120],
#         [-0.8548],
#         [ 2.3518],
#         [ 0.0473],
#         [ 0.2780],
#         [-0.9675]], requires_grad=True)
# tensor([[ 7.6039e-05],
#         [-6.7838e-02],
#         [ 4.8621e-01],
#         [-2.6509e-02],
#         [-6.5379e-02],
#         [ 1.5732e-02]], requires_grad=True)
# tensor([[ 0.0047],
#         [-0.0790],
#         [ 0.4428],
#         [-0.0535],
#         [ 0.0683],
#         [ 0.1254]], requires_grad=True)
# tensor([[ 0.0097],
#         [-0.0381],
#         [ 0.1101],
#         [-0.0363],
#         [-0.0148],
#         [ 0.1087]], requires_grad=True)
# tensor([[ 0.0022],
#         [-0.0728],
#         [ 0.4617],
#         [-0.0379],
#         [-0.0091],
#         [ 0.0967]], requires_grad=True)
# tensor([[ 0.0105],
#         [-0.0138],
#         [ 0.0826],
#         [-0.0461],
#         [-0.1023],
#         [ 0.1293]], requires_grad=True)
# tensor([[-0.1732],
#         [-0.6019],
#         [ 1.8997],
#         [ 1.0049],
#         [-1.3210],
#         [-1.0418]], requires_grad=True)
# 12500 9.4E-04 5.0E-04 3.3E-04 1.1E-04
# tensor([[ 0.1808],
#         [ 1.4746],
#         [-1.3377],
#         [-1.1066],
#         [-0.3277],
#         [-1.4170]], requires_grad=True)
# tensor([[ 0.0089],
#         [-0.0186],
#         [ 0.0994],
#         [-0.0380],
#         [-0.0799],
#         [ 0.1065]], requires_grad=True)
# tensor([[ 0.0022],
#         [-0.0632],
#         [ 0.4533],
#         [-0.0389],
#         [ 0.0185],
#         [ 0.1052]], requires_grad=True)
# tensor([[ 0.2257],
#         [-0.8294],
#         [ 1.8792],
#         [-0.2290],
#         [ 1.0217],
#         [ 0.3824]], requires_grad=True)
# tensor([[ 0.0577],
#         [ 0.9489],
#         [-0.7581],
#         [-0.4237],
#         [ 0.5449],
#         [-0.8627]], requires_grad=True)
# tensor([[ 0.1275],
#         [-0.6200],
#         [ 1.5039],
#         [-0.0522],
#         [ 0.6091],
#         [ 0.2388]], requires_grad=True)
# tensor([[ 0.3220],
#         [-0.9169],
#         [ 1.9077],
#         [-0.4656],
#         [ 1.0937],
#         [ 0.7770]], requires_grad=True)
# tensor([[-0.0415],
#         [-0.1482],
#         [ 0.9343],
#         [ 0.2295],
#         [-0.7696],
#         [-0.7740]], requires_grad=True)
# tensor([[ 0.1034],
#         [-0.7603],
#         [ 2.3037],
#         [ 0.0801],
#         [ 0.3962],
#         [-0.9389]], requires_grad=True)
# tensor([[ 0.0005],
#         [-0.0533],
#         [ 0.4713],
#         [-0.0307],
#         [-0.0520],
#         [ 0.0121]], requires_grad=True)
# tensor([[ 0.0034],
#         [-0.0658],
#         [ 0.4396],
#         [-0.0466],
#         [ 0.0479],
#         [ 0.1475]], requires_grad=True)
# tensor([[ 0.0085],
#         [-0.0380],
#         [ 0.1124],
#         [-0.0309],
#         [-0.0152],
#         [ 0.1080]], requires_grad=True)
# tensor([[ 0.0018],
#         [-0.0579],
#         [ 0.4529],
#         [-0.0360],
#         [-0.0099],
#         [ 0.1068]], requires_grad=True)
# tensor([[ 0.0093],
#         [-0.0182],
#         [ 0.0881],
#         [-0.0401],
#         [-0.0894],
#         [ 0.1260]], requires_grad=True)
# tensor([[-0.1693],
#         [-0.5662],
#         [ 1.8770],
#         [ 0.9815],
#         [-1.2824],
#         [-1.0874]], requires_grad=True)
# 13000 5.1E-04 3.1E-04 9.2E-05 1.0E-04
# tensor([[ 0.1773],
#         [ 1.4540],
#         [-1.3316],
#         [-1.0924],
#         [-0.3496],
#         [-1.4140]], requires_grad=True)
# tensor([[ 0.0086],
#         [-0.0260],
#         [ 0.1044],
#         [-0.0357],
#         [-0.0730],
#         [ 0.1108]], requires_grad=True)
# tensor([[ 0.0026],
#         [-0.0490],
#         [ 0.4444],
#         [-0.0407],
#         [ 0.0123],
#         [ 0.1169]], requires_grad=True)
# tensor([[ 0.2180],
#         [-0.7577],
#         [ 1.8848],
#         [-0.1953],
#         [ 1.0968],
#         [ 0.3709]], requires_grad=True)
# tensor([[ 0.0586],
#         [ 0.9188],
#         [-0.7475],
#         [-0.4321],
#         [ 0.5959],
#         [-0.8615]], requires_grad=True)
# tensor([[ 0.1216],
#         [-0.5536],
#         [ 1.5004],
#         [-0.0266],
#         [ 0.6529],
#         [ 0.2218]], requires_grad=True)
# tensor([[ 0.3072],
#         [-0.8282],
#         [ 1.9024],
#         [-0.4138],
#         [ 1.1819],
#         [ 0.7648]], requires_grad=True)
# tensor([[-0.0396],
#         [-0.1256],
#         [ 0.9139],
#         [ 0.2199],
#         [-0.7691],
#         [-0.7222]], requires_grad=True)
# tensor([[ 0.0974],
#         [-0.6782],
#         [ 2.2623],
#         [ 0.1100],
#         [ 0.4948],
#         [-0.9100]], requires_grad=True)
# tensor([[ 0.0016],
#         [-0.0400],
#         [ 0.4590],
#         [-0.0365],
#         [-0.0459],
#         [ 0.0160]], requires_grad=True)
# tensor([[ 0.0034],
#         [-0.0519],
#         [ 0.4340],
#         [-0.0455],
#         [ 0.0327],
#         [ 0.1634]], requires_grad=True)
# tensor([[ 0.0081],
#         [-0.0420],
#         [ 0.1164],
#         [-0.0286],
#         [-0.0179],
#         [ 0.1091]], requires_grad=True)
# tensor([[ 0.0023],
#         [-0.0431],
#         [ 0.4430],
#         [-0.0394],
#         [-0.0080],
#         [ 0.1129]], requires_grad=True)
# tensor([[ 0.0089],
#         [-0.0269],
#         [ 0.0957],
#         [-0.0375],
#         [-0.0790],
#         [ 0.1255]], requires_grad=True)
# tensor([[-0.1649],
#         [-0.5344],
#         [ 1.8746],
#         [ 0.9567],
#         [-1.2397],
#         [-1.0851]], requires_grad=True)
# 13500 4.2E-04 2.4E-04 8.0E-05 1.0E-04
# tensor([[ 0.1741],
#         [ 1.4400],
#         [-1.3249],
#         [-1.0760],
#         [-0.3724],
#         [-1.4093]], requires_grad=True)
# tensor([[ 0.0078],
#         [-0.0304],
#         [ 0.1088],
#         [-0.0312],
#         [-0.0675],
#         [ 0.1119]], requires_grad=True)
# tensor([[ 0.0026],
#         [-0.0382],
#         [ 0.4351],
#         [-0.0408],
#         [ 0.0099],
#         [ 0.1267]], requires_grad=True)
# tensor([[ 0.2082],
#         [-0.6956],
#         [ 1.8844],
#         [-0.1578],
#         [ 1.1573],
#         [ 0.3576]], requires_grad=True)
# tensor([[ 0.0599],
#         [ 0.8835],
#         [-0.7380],
#         [-0.4381],
#         [ 0.6298],
#         [-0.8608]], requires_grad=True)
# tensor([[ 1.1426e-01],
#         [-4.9626e-01],
#         [ 1.4933e+00],
#         [ 9.5207e-04],
#         [ 6.8621e-01],
#         [ 2.0267e-01]], requires_grad=True)
# tensor([[ 0.2913],
#         [-0.7504],
#         [ 1.8918],
#         [-0.3603],
#         [ 1.2560],
#         [ 0.7517]], requires_grad=True)
# tensor([[-0.0381],
#         [-0.1073],
#         [ 0.8878],
#         [ 0.2117],
#         [-0.7673],
#         [-0.6542]], requires_grad=True)
# tensor([[ 0.0895],
#         [-0.6122],
#         [ 2.2179],
#         [ 0.1394],
#         [ 0.5636],
#         [-0.8782]], requires_grad=True)
# tensor([[ 0.0019],
#         [-0.0305],
#         [ 0.4488],
#         [-0.0380],
#         [-0.0436],
#         [ 0.0270]], requires_grad=True)
# tensor([[ 0.0032],
#         [-0.0410],
#         [ 0.4266],
#         [-0.0441],
#         [ 0.0256],
#         [ 0.1741]], requires_grad=True)
# tensor([[ 0.0071],
#         [-0.0442],
#         [ 0.1211],
#         [-0.0239],
#         [-0.0211],
#         [ 0.1076]], requires_grad=True)
# tensor([[ 0.0025],
#         [-0.0319],
#         [ 0.4332],
#         [-0.0405],
#         [-0.0046],
#         [ 0.1182]], requires_grad=True)
# tensor([[ 0.0080],
#         [-0.0325],
#         [ 0.1024],
#         [-0.0327],
#         [-0.0700],
#         [ 0.1222]], requires_grad=True)
# tensor([[-0.1599],
#         [-0.5091],
#         [ 1.8495],
#         [ 0.9293],
#         [-1.1949],
#         [-1.0591]], requires_grad=True)
# 14000 3.3E-04 1.8E-04 5.3E-05 9.8E-05
# tensor([[ 0.1704],
#         [ 1.4248],
#         [-1.3215],
#         [-1.0587],
#         [-0.3962],
#         [-1.4046]], requires_grad=True)
# tensor([[ 0.0072],
#         [-0.0326],
#         [ 0.1126],
#         [-0.0281],
#         [-0.0642],
#         [ 0.1107]], requires_grad=True)
# tensor([[ 0.0026],
#         [-0.0251],
#         [ 0.4271],
#         [-0.0412],
#         [ 0.0091],
#         [ 0.1359]], requires_grad=True)
# tensor([[ 0.1984],
#         [-0.6421],
#         [ 1.8801],
#         [-0.1200],
#         [ 1.2085],
#         [ 0.3445]], requires_grad=True)
# tensor([[ 0.0605],
#         [ 0.8631],
#         [-0.7297],
#         [-0.4438],
#         [ 0.6590],
#         [-0.8604]], requires_grad=True)
# tensor([[ 0.1071],
#         [-0.4490],
#         [ 1.4852],
#         [ 0.0277],
#         [ 0.7107],
#         [ 0.1829]], requires_grad=True)
# tensor([[ 0.2751],
#         [-0.6851],
#         [ 1.8775],
#         [-0.3064],
#         [ 1.3183],
#         [ 0.7385]], requires_grad=True)
# tensor([[-0.0369],
#         [-0.0896],
#         [ 0.8653],
#         [ 0.2045],
#         [-0.7639],
#         [-0.5788]], requires_grad=True)
# tensor([[ 0.0826],
#         [-0.5585],
#         [ 2.1775],
#         [ 0.1673],
#         [ 0.6150],
#         [-0.8467]], requires_grad=True)
# tensor([[ 0.0019],
#         [-0.0187],
#         [ 0.4412],
#         [-0.0384],
#         [-0.0431],
#         [ 0.0411]], requires_grad=True)
# tensor([[ 0.0030],
#         [-0.0276],
#         [ 0.4194],
#         [-0.0437],
#         [ 0.0229],
#         [ 0.1819]], requires_grad=True)
# tensor([[ 0.0064],
#         [-0.0444],
#         [ 0.1252],
#         [-0.0209],
#         [-0.0254],
#         [ 0.1037]], requires_grad=True)
# tensor([[ 0.0026],
#         [-0.0186],
#         [ 0.4251],
#         [-0.0415],
#         [-0.0016],
#         [ 0.1241]], requires_grad=True)
# tensor([[ 0.0073],
#         [-0.0357],
#         [ 0.1080],
#         [-0.0295],
#         [-0.0632],
#         [ 0.1173]], requires_grad=True)
# tensor([[-0.1548],
#         [-0.4878],
#         [ 1.8285],
#         [ 0.9006],
#         [-1.1522],
#         [-1.0077]], requires_grad=True)
# 14500 3.2E-04 1.7E-04 6.2E-05 9.6E-05
# tensor([[ 0.1667],
#         [ 1.4110],
#         [-1.3189],
#         [-1.0382],
#         [-0.4202],
#         [-1.3996]], requires_grad=True)
# tensor([[ 0.0066],
#         [-0.0341],
#         [ 0.1164],
#         [-0.0258],
#         [-0.0624],
#         [ 0.1096]], requires_grad=True)
# tensor([[ 0.0021],
#         [-0.0164],
#         [ 0.4224],
#         [-0.0392],
#         [ 0.0107],
#         [ 0.1469]], requires_grad=True)
# tensor([[ 0.1876],
#         [-0.5966],
#         [ 1.8731],
#         [-0.0844],
#         [ 1.2496],
#         [ 0.3320]], requires_grad=True)
# tensor([[ 0.0616],
#         [ 0.8409],
#         [-0.7216],
#         [-0.4462],
#         [ 0.6744],
#         [-0.8599]], requires_grad=True)
# tensor([[ 0.0999],
#         [-0.4095],
#         [ 1.4772],
#         [ 0.0511],
#         [ 0.7285],
#         [ 0.1650]], requires_grad=True)
# tensor([[ 0.2587],
#         [-0.6290],
#         [ 1.8618],
#         [-0.2571],
#         [ 1.3684],
#         [ 0.7269]], requires_grad=True)
# tensor([[-0.0355],
#         [-0.0740],
#         [ 0.8397],
#         [ 0.1964],
#         [-0.7525],
#         [-0.5024]], requires_grad=True)
# tensor([[ 0.0756],
#         [-0.5162],
#         [ 2.1423],
#         [ 0.1913],
#         [ 0.6517],
#         [-0.8144]], requires_grad=True)
# tensor([[ 0.0014],
#         [-0.0111],
#         [ 0.4369],
#         [-0.0360],
#         [-0.0412],
#         [ 0.0590]], requires_grad=True)
# tensor([[ 0.0025],
#         [-0.0185],
#         [ 0.4151],
#         [-0.0415],
#         [ 0.0242],
#         [ 0.1904]], requires_grad=True)
# tensor([[ 0.0057],
#         [-0.0447],
#         [ 0.1292],
#         [-0.0186],
#         [-0.0292],
#         [ 0.1015]], requires_grad=True)
# tensor([[ 0.0021],
#         [-0.0096],
#         [ 0.4204],
#         [-0.0399],
#         [ 0.0022],
#         [ 0.1333]], requires_grad=True)
# tensor([[ 0.0067],
#         [-0.0378],
#         [ 0.1128],
#         [-0.0270],
#         [-0.0587],
#         [ 0.1135]], requires_grad=True)
# tensor([[-0.1490],
#         [-0.4611],
#         [ 1.7975],
#         [ 0.8682],
#         [-1.1089],
#         [-0.9387]], requires_grad=True)

# %%
time_deriv_list, theta, coeff_vector_list
# Out:
# ([tensor([[-3.5103e-04],
#           [-8.9976e-04],
#           [ 6.2787e-03],
#           [-3.4550e-02],
#           [ 5.8237e-03],
#           [-6.6269e-03],
#           [-6.9005e-03],
#           [ 3.7091e-02],
#           [-3.2234e-03],
#           [ 5.1505e-03],
#           [-6.6052e-03],
#           [ 1.0409e-02],
#           [-3.1594e-02],
#           [-2.7961e-03],
#           [-4.9917e-02],
#           [-4.4290e-01],
#           [-9.4030e-03],
#           [-8.6908e-04],
#           [-2.8255e-01],
#           [ 3.9451e-03],
#           [ 3.0013e-02],
#           [-4.5826e-03],
#           [-1.3797e-02],
#           [-6.0160e-03],
#           [ 4.7594e-02],
#           [-6.8794e-03],
#           [-9.8440e-03],
#           [-9.9844e-03],
#           [-1.3054e-02],
#           [-9.9151e-03],
#           [-5.7676e-03],
#           [-8.3162e-03],
#           [-4.0225e-04],
#           [-9.1645e-03],
#           [-4.8667e-03],
#           [-1.2958e-02],
#           [-2.3425e-03],
#           [ 8.2686e-02],
#           [-3.2294e-02],
#           [-4.5452e-02],
#           [-1.5212e-02],
#           [-7.4591e-04],
#           [-1.1533e-02],
#           [-4.0591e-02],
#           [-1.5329e-03],
#           [ 1.0213e-01],
#           [-1.9781e-01],
#           [-4.3683e-02],
#           [-6.3318e-03],
#           [-1.2688e-02],
#           [ 6.2775e-04],
#           [ 1.3838e-02],
#           [ 9.8489e-03],
#           [-1.2352e-01],
#           [-6.1137e-03],
#           [-2.8830e-04],
#           [-6.7177e-03],
#           [-9.6457e-03],
#           [-1.5598e-02],
#           [ 1.5229e-03],
#           [ 6.1130e-04],
#           [-8.2527e-04],
#           [-4.6697e-03],
#           [-1.3156e-01],
#           [ 2.7781e-02],
#           [-1.3486e-02],
#           [ 8.0154e-03],
#           [-2.0041e-02],
#           [-5.2060e-03],
#           [-4.4463e-03],
#           [-1.5324e-02],
#           [ 2.0973e-02],
#           [-4.1732e-03],
#           [-3.6683e-03],
#           [ 2.5460e-02],
#           [-4.1218e-03],
#           [-1.8108e-02],
#           [-3.1672e-02],
#           [ 2.4380e-02],
#           [ 1.4843e-02],
#           [-4.3402e-02],
#           [-7.5024e-03],
#           [-6.9944e-02],
#           [ 3.5440e-02],
#           [-9.6453e-03],
#           [-6.8392e-03],
#           [-1.2358e-02],
#           [ 1.0000e-03],
#           [-1.0176e-02],
#           [ 2.0592e-02],
#           [ 3.1727e-03],
#           [-6.9939e-02],
#           [-2.2191e-03],
#           [-2.1400e-02],
#           [ 4.2793e-03],
#           [-1.3563e-02],
#           [-1.0694e-02],
#           [ 4.3571e-02],
#           [-6.9632e-03],
#           [-4.7011e-03]], grad_fn=<SliceBackward>), tensor([[ 9.8633e-03],
#           [ 9.5215e-03],
#           [ 3.9563e-03],
#           [-2.7789e-02],
#           [ 1.0630e-02],
#           [-6.5377e-03],
#           [-9.9266e-03],
#           [ 6.0032e-03],
#           [ 1.3719e-02],
#           [ 6.6856e-03],
#           [-3.1018e-04],
#           [ 1.4527e-03],
#           [ 2.8916e-02],
#           [ 1.0044e-02],
#           [ 3.7177e-02],
#           [-1.4570e-01],
#           [ 1.4986e-03],
#           [ 1.1254e-02],
#           [-1.9963e-01],
#           [ 6.1299e-03],
#           [ 1.7037e-03],
#           [ 6.0284e-03],
#           [ 2.3620e-03],
#           [-3.5672e-03],
#           [ 6.3782e-03],
#           [-8.1194e-03],
#           [ 1.0790e-03],
#           [-1.4000e-02],
#           [-2.0272e-02],
#           [-2.8653e-03],
#           [-4.2176e-04],
#           [-1.6023e-02],
#           [ 8.8407e-03],
#           [-1.0779e-02],
#           [ 1.7047e-02],
#           [ 7.2011e-02],
#           [ 9.1819e-03],
#           [ 8.1042e-02],
#           [-3.5371e-02],
#           [-3.9992e-02],
#           [-2.6892e-02],
#           [ 1.7656e-02],
#           [-1.1808e-02],
#           [-5.5955e-02],
#           [ 1.6663e-02],
#           [ 2.6879e-02],
#           [-1.1633e-01],
#           [ 1.2853e-02],
#           [ 5.0970e-03],
#           [ 9.1748e-03],
#           [ 7.2021e-03],
#           [ 1.8196e-02],
#           [ 1.0586e-02],
#           [-7.2690e-03],
#           [ 1.3674e-02],
#           [ 8.4952e-03],
#           [-3.0111e-03],
#           [-1.3386e-02],
#           [-2.4602e-02],
#           [ 2.1629e-02],
#           [ 9.6518e-03],
#           [ 8.7731e-03],
#           [ 4.9587e-03],
#           [-8.8303e-02],
#           [ 1.4816e-03],
#           [-1.8749e-02],
#           [ 5.1136e-03],
#           [ 1.9275e-02],
#           [ 7.8583e-03],
#           [ 1.0709e-02],
#           [-7.4497e-05],
#           [-3.1904e-04],
#           [ 3.7093e-03],
#           [ 8.2513e-03],
#           [ 6.9739e-04],
#           [ 6.3180e-03],
#           [-3.0609e-02],
#           [-3.9583e-02],
#           [ 2.9533e-04],
#           [ 6.4079e-03],
#           [-3.5078e-02],
#           [ 1.4307e-02],
#           [-5.6180e-02],
#           [ 2.3705e-03],
#           [ 6.1117e-03],
#           [-1.3590e-02],
#           [-9.7510e-03],
#           [ 1.1512e-02],
#           [-1.5866e-02],
#           [ 4.0022e-03],
#           [ 5.6193e-03],
#           [ 1.1669e-02],
#           [ 6.6304e-03],
#           [-1.6410e-02],
#           [ 5.8689e-03],
#           [-3.5199e-03],
#           [-1.0821e-02],
#           [ 3.2135e-03],
#           [ 6.0680e-03],
#           [ 5.9663e-02]], grad_fn=<SliceBackward>), tensor([[-3.0204e-03],
#           [-2.5945e-03],
#           [ 4.7596e-03],
#           [-4.0630e-02],
#           [ 3.1111e-02],
#           [-1.0668e-02],
#           [-1.1853e-02],
#           [ 8.4075e-01],
#           [-4.7495e-03],
#           [ 9.4963e-03],
#           [-7.7050e-03],
#           [ 1.6466e-02],
#           [ 5.8353e-02],
#           [-3.7882e-03],
#           [-1.0988e-01],
#           [-4.7315e-01],
#           [-7.3246e-03],
#           [-6.2835e-03],
#           [-1.1001e-01],
#           [-1.1369e-03],
#           [-1.1574e-01],
#           [-6.0398e-03],
#           [-2.1786e-02],
#           [-1.3818e-02],
#           [-7.8207e-02],
#           [-1.0962e-02],
#           [-7.5793e-03],
#           [-9.1463e-03],
#           [-9.0092e-03],
#           [-7.6479e-03],
#           [-8.8328e-03],
#           [-1.2043e-02],
#           [-2.0871e-03],
#           [-8.4747e-03],
#           [-5.1831e-03],
#           [-4.1622e-03],
#           [-3.6345e-03],
#           [ 1.7378e-01],
#           [-6.5367e-02],
#           [-6.4051e-02],
#           [-1.0428e-02],
#           [-1.0521e-03],
#           [-8.5088e-03],
#           [-5.1823e-02],
#           [-1.9792e-03],
#           [ 2.2496e-01],
#           [-6.8268e-02],
#           [-6.5116e-02],
#           [-6.2433e-03],
#           [-1.1575e-02],
#           [-3.0945e-04],
#           [ 4.1087e-02],
#           [ 1.4911e-02],
#           [-1.9140e-02],
#           [-6.5724e-03],
#           [-2.2109e-03],
#           [-8.7763e-03],
#           [-8.6583e-03],
#           [-1.1555e-02],
#           [ 8.6791e-04],
#           [-3.2546e-03],
#           [-2.6368e-03],
#           [-9.5718e-03],
#           [-1.4121e-01],
#           [ 1.0574e-01],
#           [-9.5124e-03],
#           [ 8.5162e-03],
#           [-2.5068e-02],
#           [-5.2175e-03],
#           [-5.4853e-03],
#           [-1.2974e-02],
#           [-1.5692e-01],
#           [-8.1643e-03],
#           [-4.7600e-03],
#           [ 2.6366e-03],
#           [-7.8996e-03],
#           [-1.4517e-02],
#           [-3.3930e-02],
#           [ 4.3406e-02],
#           [ 1.9913e-02],
#           [-5.9643e-02],
#           [-2.1165e-02],
#           [ 6.1149e-03],
#           [ 6.8718e-02],
#           [-1.0620e-02],
#           [-1.5136e-02],
#           [-9.3278e-03],
#           [-7.1585e-04],
#           [-8.7520e-03],
#           [ 3.9232e-02],
#           [ 3.2103e-04],
#           [-1.2835e-01],
#           [-6.6446e-03],
#           [-3.4098e-02],
#           [-7.6790e-04],
#           [-1.4611e-02],
#           [-8.3748e-03],
#           [ 3.2337e-01],
#           [-6.0316e-03],
#           [ 1.6549e-02]], grad_fn=<SliceBackward>), tensor([[ 9.2213e-03],
#           [ 9.2326e-03],
#           [ 4.0305e-03],
#           [-2.7776e-02],
#           [ 1.2955e-02],
#           [-6.9104e-03],
#           [-1.0203e-02],
#           [ 4.3102e-04],
#           [ 1.3475e-02],
#           [ 9.7829e-03],
#           [-7.3993e-04],
#           [ 8.0096e-04],
#           [ 2.5693e-02],
#           [ 9.7160e-03],
#           [ 3.0407e-02],
#           [-1.4243e-01],
#           [ 1.2648e-03],
#           [ 1.0588e-02],
#           [-1.9262e-01],
#           [ 5.0784e-03],
#           [ 1.1183e-03],
#           [ 5.4674e-03],
#           [ 1.6122e-03],
#           [-2.9197e-03],
#           [ 1.2226e-03],
#           [-8.4379e-03],
#           [ 8.3168e-04],
#           [-1.3604e-02],
#           [-1.9944e-02],
#           [-3.0172e-03],
#           [-9.4482e-04],
#           [-1.5668e-02],
#           [ 8.7281e-03],
#           [-1.0802e-02],
#           [ 1.6961e-02],
#           [ 6.0649e-02],
#           [ 8.8351e-03],
#           [ 7.7090e-02],
#           [-3.4321e-02],
#           [-3.9740e-02],
#           [-2.6633e-02],
#           [ 1.6810e-02],
#           [-1.1804e-02],
#           [-5.4763e-02],
#           [ 1.6066e-02],
#           [ 2.8599e-02],
#           [-1.0842e-01],
#           [ 1.4706e-02],
#           [ 5.0801e-03],
#           [ 9.5008e-03],
#           [ 6.7010e-03],
#           [ 2.1728e-02],
#           [ 1.0987e-02],
#           [-1.2071e-02],
#           [ 1.3642e-02],
#           [ 8.4449e-03],
#           [-3.4164e-03],
#           [-1.3300e-02],
#           [-2.4341e-02],
#           [ 2.0085e-02],
#           [ 8.6174e-03],
#           [ 8.6187e-03],
#           [ 5.5626e-03],
#           [-8.4349e-02],
#           [ 2.8501e-04],
#           [-1.8494e-02],
#           [ 4.4091e-03],
#           [ 1.9388e-02],
#           [ 7.7207e-03],
#           [ 1.0321e-02],
#           [ 7.0865e-05],
#           [ 1.5565e-03],
#           [ 3.0507e-03],
#           [ 7.7690e-03],
#           [-3.2505e-04],
#           [ 6.7763e-03],
#           [-3.0380e-02],
#           [-3.8735e-02],
#           [ 5.3761e-04],
#           [ 6.2014e-03],
#           [-3.4877e-02],
#           [ 1.3718e-02],
#           [-1.0588e-02],
#           [ 4.8044e-02],
#           [-7.1989e-03],
#           [-3.2086e-03]], grad_fn=<SliceBackward>), tensor([[ 9.0992e-03],
#           [ 9.1640e-03],
#           [ 3.8354e-03],
#           [-2.7726e-02],
#           [ 1.3292e-02],
#           [-6.6934e-03],
#           [-9.9867e-03],
#           [ 1.2579e-03],
#           [ 1.3550e-02],
#           [ 9.7646e-03],
#           [-5.6576e-04],
#           [ 1.1656e-04],
#           [ 2.5564e-02],
#           [ 9.7234e-03],
#           [ 3.1117e-02],
#           [-1.4243e-01],
#           [ 1.1948e-03],
#           [ 1.0428e-02],
#           [-1.9149e-01],
#           [ 4.8296e-03],
#           [ 1.3965e-03],
#           [ 5.6157e-03],
#           [ 1.7145e-03],
#           [-2.7665e-03],
#           [ 1.5506e-03],
#           [-8.2270e-03],
#           [ 7.5778e-04],
#           [-1.3667e-02],
#           [-1.9978e-02],
#           [-3.1028e-03],
#           [-7.3642e-04],
#           [-1.5589e-02],
#           [ 8.6692e-03],
#           [-1.0692e-02],
#           [ 1.7168e-02],
#           [ 6.1430e-02],
#           [ 8.8761e-03],
#           [ 7.6652e-02],
#           [-3.4261e-02],
#           [-3.9822e-02],
#           [-2.6827e-02],
#           [ 1.7062e-02],
#           [-1.1936e-02],
#           [-5.4753e-02],
#           [ 1.6295e-02],
#           [ 2.8523e-02],
#           [-1.0770e-01],
#           [ 1.4364e-02],
#           [ 5.0460e-03],
#           [ 9.6064e-03],
#           [ 6.8661e-03],
#           [ 2.1060e-02],
#           [ 1.0666e-02],
#           [-1.0676e-02],
#           [ 1.3714e-02],
#           [ 8.4124e-03],
#           [-3.2263e-03],
#           [-1.3214e-02],
#           [-2.4414e-02],
#           [ 2.0296e-02],
#           [ 8.4415e-03],
#           [ 8.6092e-03],
#           [ 5.6170e-03],
#           [-8.4100e-02],
#           [ 1.6872e-03],
#           [-1.8513e-02],
#           [ 4.2275e-03],
#           [ 1.9440e-02],
#           [ 7.6823e-03],
#           [ 1.0346e-02],
#           [ 6.3509e-05],
#           [ 1.6895e-03],
#           [ 3.2579e-03],
#           [ 7.8684e-03],
#           [ 6.2808e-04],
#           [ 6.7946e-03],
#           [-3.0505e-02],
#           [-3.8789e-02],
#           [ 6.4146e-04],
#           [ 6.0147e-03],
#           [-3.4947e-02],
#           [ 1.3702e-02],
#           [-6.1301e-02],
#           [ 1.8555e-03],
#           [ 5.8201e-03],
#           [-1.3205e-02],
#           [-9.6396e-03],
#           [ 1.1016e-02],
#           [-1.5606e-02],
#           [ 4.3669e-03],
#           [ 5.9159e-03],
#           [ 7.6835e-03],
#           [ 6.1441e-03],
#           [-1.6851e-02],
#           [ 4.1024e-03],
#           [-3.7389e-03],
#           [-1.0828e-02],
#           [ 1.2919e-04],
#           [ 5.8541e-03],
#           [ 5.2175e-02]], grad_fn=<SliceBackward>)],
#  [tensor([[ 1.0000e+00,  3.0286e-02, -2.7283e-04,  1.1554e-01,  3.4991e-03,
#            -3.1521e-05],
#           [ 1.0000e+00, -1.3127e-01, -2.0630e-01,  4.6954e-01, -6.1637e-02,
#            -9.6866e-02],
#           [ 1.0000e+00,  3.8468e-03,  2.6236e-03, -6.2001e-04, -2.3851e-06,
#            -1.6266e-06],
#           [ 1.0000e+00,  1.7020e-02,  3.3478e-02,  7.9803e-03,  1.3583e-04,
#             2.6716e-04],
#           [ 1.0000e+00, -2.6192e-01, -1.8325e-01,  4.5827e-01, -1.2003e-01,
#            -8.3977e-02],
#           [ 1.0000e+00,  1.4019e-01,  7.0501e-02,  1.5537e-01,  2.1782e-02,
#             1.0954e-02],
#           [ 1.0000e+00,  2.9638e-01, -3.1329e-01,  5.3865e-01,  1.5964e-01,
#            -1.6876e-01],
#           [ 1.0000e+00, -4.4038e-03,  6.5032e-03,  1.8909e-03, -8.3272e-06,
#             1.2297e-05],
#           [ 1.0000e+00,  1.4892e-01,  3.0304e-02,  2.1387e-01,  3.1850e-02,
#             6.4811e-03],
#           [ 1.0000e+00, -3.2651e-02, -7.0053e-02,  3.2817e-01, -1.0715e-02,
#            -2.2990e-02],
#           [ 1.0000e+00,  1.2894e-01, -5.4590e-02,  3.1392e-01,  4.0477e-02,
#            -1.7137e-02],
#           [ 1.0000e+00, -5.0907e-02,  5.0854e-02,  3.7656e-02, -1.9170e-03,
#             1.9150e-03],
#           [ 1.0000e+00,  6.7332e-02, -7.8304e-02,  3.4044e-01,  2.2922e-02,
#            -2.6658e-02],
#           [ 1.0000e+00,  1.1128e-02,  2.4926e-02,  4.3181e-03,  4.8053e-05,
#             1.0763e-04],
#           [ 1.0000e+00, -2.5697e-02,  2.7575e-02,  1.4751e-02, -3.7907e-04,
#             4.0677e-04],
#           [ 1.0000e+00,  4.3583e-01,  4.4321e-02,  4.0628e-01,  1.7707e-01,
#             1.8007e-02],
#           [ 1.0000e+00,  7.5955e-02,  3.4066e-02,  1.0844e-01,  8.2365e-03,
#             3.6941e-03],
#           [ 1.0000e+00,  1.7688e-01, -8.7727e-02,  3.6969e-01,  6.5392e-02,
#            -3.2432e-02],
#           [ 1.0000e+00,  1.6096e-02,  2.6507e-02,  1.0492e-02,  1.6887e-04,
#             2.7809e-04],
#           [ 1.0000e+00,  1.6040e-01, -2.3697e-02,  2.9152e-01,  4.6759e-02,
#            -6.9083e-03],
#           [ 1.0000e+00, -1.1416e-01, -5.6142e-02,  3.0652e-01, -3.4993e-02,
#            -1.7208e-02],
#           [ 1.0000e+00, -1.8434e-03,  1.6587e-03,  1.7167e-03, -3.1646e-06,
#             2.8474e-06],
#           [ 1.0000e+00,  1.2366e-01,  3.1580e-02,  1.8050e-01,  2.2320e-02,
#             5.7000e-03],
#           [ 1.0000e+00, -2.3705e-01,  2.7265e-01,  1.4176e-01, -3.3604e-02,
#             3.8651e-02]], grad_fn=<ViewBackward>)],
#  [tensor([[-1.6641],
#           [-1.0621],
#           [-0.7923],
#           [-0.5430],
#           [-1.5961],
#           [ 0.1786]], requires_grad=True), tensor([[ 1.0134],
#           [-0.1902],
#           [-1.8798],
#           [-0.8896],
#           [ 0.3539],
#           [ 0.9040]], requires_grad=True), tensor([[-2.0148],
#           [ 0.5033],
#           [-0.1957],
#           [ 1.4061],
#           [-1.5410],
#           [ 0.5958]], requires_grad=True), tensor([[ 1.4760],
#           [-0.9127],
#           [ 0.4444],
#           [ 0.3634],
#           [-0.4820],
#           [-1.2989]], requires_grad=True), tensor([[-1.5676],
#           [-0.3755],
#           [ 0.1492],
#           [-0.4325],
#           [-0.6334],
#           [ 0.4068]], requires_grad=True), tensor([[ 1.2709],
#           [-0.1740],
#           [ 1.0870],
#           [ 1.9622],
#           [-1.3095],
#           [ 1.1523]], requires_grad=True), tensor([[ 0.5384],
#           [ 0.1670],
#           [-0.7486],
#           [ 0.3008],
#           [ 0.7477],
#           [-0.4069]], requires_grad=True)])

# %%
scaling_time = torch.norm(time_deriv_list[2], dim=0)
scaling_theta = torch.norm(theta[2], dim=0)[:, None]

# %%
theta[1]
# Out:
# tensor([[ 1.0000e+00, -1.6343e-02, -7.4862e-03,  1.5429e-01, -2.5216e-03,
#          -1.1550e-03],
#         [ 1.0000e+00,  2.4805e-02, -2.1134e-02,  2.1427e-01,  5.3149e-03,
#          -4.5284e-03],
#         [ 1.0000e+00,  5.6727e-03,  8.5658e-03,  1.1644e-01,  6.6056e-04,
#           9.9744e-04],
#         ...,
#         [ 1.0000e+00, -1.3975e-02, -5.5810e-03,  1.5304e-01, -2.1388e-03,
#          -8.5412e-04],
#         [ 1.0000e+00, -4.1864e-02, -1.5580e-02,  1.7825e-01, -7.4625e-03,
#          -2.7771e-03],
#         [ 1.0000e+00, -1.8922e-02, -1.9203e-02,  1.9054e-01, -3.6054e-03,
#          -3.6591e-03]], grad_fn=<ViewBackward>)

# %%
scaled_coeff_vector_list = [scaling(coeff_vector, theta[2], time_deriv) for coeff_vector, time_deriv in zip(coeff_vector_list[2], time_deriv_list[2])]

# %%
coeff_vector.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-143-0d07ad87e3f1> in <module>
# ----> 1 coeff_vector.shape
#
# NameError: name 'coeff_vector' is not defined

# %%
sparse_coeff_vector_list, sparsity_mask_list = zip(*[threshold(scaled_coeff_vector, coeff_vector) for scaled_coeff_vector, coeff_vector in zip(scaled_coeff_vector_list[0], coeff_vector_list[0])])

# %%
sparse_coeff_vector_list
# Out:
# (tensor([], requires_grad=True),
#  tensor([], requires_grad=True),
#  tensor([], requires_grad=True),
#  tensor([], requires_grad=True),
#  tensor([], requires_grad=True),
#  tensor([], requires_grad=True))

# %%
prediction = network(X_train)

# %%
time_deriv_list, theta = library_1D_in(X_train, prediction, library_config)

# %%
y_reg = time_deriv_list[0].detach().numpy()
x_reg = theta.detach().numpy()

# %%
np.linalg.lstsq(x_reg,y_reg,rcond=None)
# Out:
# (array([[ 1.01022534e-01],
#         [ 8.01657885e-03],
#         [ 1.61606614e-02],
#         [ 1.19942088e-04],
#         [ 9.29686939e-06],
#         [-1.57570746e-02],
#         [-8.46816242e-01],
#         [-3.48056555e-02],
#         [-8.19199078e-04],
#         [-5.23904100e-06]], dtype=float32),
#  array([37180.695], dtype=float32),
#  10,
#  array([7.6361475e+05, 3.1920612e+05, 2.2900121e+04, 9.6409893e+03,
#         5.7146167e+02, 5.0050757e+02, 7.1360893e+01, 4.8615910e+01,
#         3.0338158e+01, 2.5171886e+01], dtype=float32))

# %%
vec =np.linalg.lstsq(x_reg,y_reg,rcond=None)[0]

# %%
coeff_vector = [torch.tensor(vec, dtype=torch.float32, requires_grad=True)]

# %%
coeff_vector_list
# Out:
# [tensor([[ 0.2931],
#          [ 0.7618],
#          [ 1.7404],
#          [ 0.6688],
#          [ 0.4718],
#          [ 0.7023],
#          [-1.8055],
#          [ 0.4180],
#          [-0.9910],
#          [-1.9994]], requires_grad=True)]

# %%
X_all = torch.tensor(X, dtype=torch.float32, requires_grad=True) 
prediction_full = network(X_all)

# %%
plt.imshow(prediction_full.detach().numpy().reshape(513,201), aspect='auto', cmap='coolwarm')

# %%
optim_config = {'lambda': 10**-5, 'max_iterations': 5000, 'type': 'full'}

# %%
time_deriv_list, theta, coeff_vector_list = train(X_train, y_train, network, coeff_vector_list, sparsity_mask_list, library_config, optim_config)
# Out:
# Epoch | Total loss | MSE | PI | L1
# 0 8.0E+08 2.0E-04 8.0E+08 7.0E-02
# tensor([[ 0.2951],
#         [ 0.7638],
#         [ 1.7384],
#         [ 0.6708],
#         [ 0.4738],
#         [ 0.7043],
#         [-1.8035],
#         [ 0.4160],
#         [-0.9890],
#         [-1.9974]], requires_grad=True)
# 500 1.4E+03 7.6E-01 1.4E+03 3.0E-03
# tensor([[ 0.2987],
#         [ 0.7776],
#         [ 1.7417],
#         [ 0.6796],
#         [ 0.4826],
#         [ 0.7090],
#         [-1.7850],
#         [ 0.4027],
#         [-0.9794],
#         [-1.9865]], requires_grad=True)
# 1000 5.7E+02 7.7E-01 5.7E+02 2.2E-03
# tensor([[ 0.3244],
#         [ 0.7770],
#         [ 1.7439],
#         [ 0.6796],
#         [ 0.4824],
#         [ 0.7035],
#         [-1.7849],
#         [ 0.4027],
#         [-0.9794],
#         [-1.9865]], requires_grad=True)
# 1500 2.7E+02 7.7E-01 2.7E+02 1.7E-03
# tensor([[ 0.3575],
#         [ 0.7765],
#         [ 1.7455],
#         [ 0.6795],
#         [ 0.4823],
#         [ 0.6992],
#         [-1.7849],
#         [ 0.4026],
#         [-0.9794],
#         [-1.9865]], requires_grad=True)
# 2000 1.5E+02 7.6E-01 1.5E+02 1.4E-03
# tensor([[ 0.3800],
#         [ 0.7758],
#         [ 1.7468],
#         [ 0.6795],
#         [ 0.4822],
#         [ 0.6973],
#         [-1.7849],
#         [ 0.4026],
#         [-0.9794],
#         [-1.9865]], requires_grad=True)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-87-1faecb290eeb> in <module>
# ----> 1 time_deriv_list, theta, coeff_vector_list = train(X_train, y_train, network, coeff_vector_list, sparsity_mask_list, library_config, optim_config)
#
# /home/working/src/deepymod_torch/neural_net.py in train(data, target, network, coeff_vector_list, sparsity_mask_list, library_config, optim_config)
#     152         # Optimizer step
#     153         optimizer.zero_grad()
# --> 154         loss.backward()
#     155         optimizer.step()
#     156
#
# /opt/conda/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     105                 products. Defaults to ``False``.
#     106         """
# --> 107         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     108
#     109     def register_hook(self, hook):
#
# /opt/conda/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      91     Variable._execution_engine.run_backward(
#      92         tensors, grad_tensors, retain_graph, create_graph,
# ---> 93         allow_unreachable=True)  # allow_unreachable flag
#      94
#      95
#
# KeyboardInterrupt:

# %%
time_deriv_list, theta, coeff_vector_list = train(X_train, y_train, network, coeff_vector, sparsity_mask_list, library_config, optim_config)
# Out:
# Epoch | Total loss | MSE | PI | L1
# 0 6.0E-02 5.6E-02 3.5E-03 1.9E-05
# tensor([[-0.0092],
#         [ 1.1719],
#         [-0.1080],
#         [-0.3816],
#         [ 0.0055],
#         [-0.0671],
#         [-1.1829],
#         [ 0.1687],
#         [-0.0087],
#         [-0.0136]], requires_grad=True)
# 500 2.6E-01 7.9E-02 1.8E-01 1.8E-05
# tensor([[-0.0353],
#         [ 1.1866],
#         [-0.1115],
#         [-0.4098],
#         [ 0.0027],
#         [-0.0328],
#         [-1.1152],
#         [ 0.2151],
#         [ 0.0075],
#         [-0.0176]], requires_grad=True)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-48eb9103e246> in <module>
# ----> 1 time_deriv_list, theta, coeff_vector_list = train(X_train, y_train, network, coeff_vector, sparsity_mask_list, library_config, optim_config)
#
# /home/working/src/deepymod_torch/neural_net.py in train(data, target, network, coeff_vector_list, sparsity_mask_list, library_config, optim_config)
#     152         # Optimizer step
#     153         optimizer.zero_grad()
# --> 154         loss.backward()
#     155         optimizer.step()
#     156
#
# /opt/conda/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     105                 products. Defaults to ``False``.
#     106         """
# --> 107         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     108
#     109     def register_hook(self, hook):
#
# /opt/conda/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      91     Variable._execution_engine.run_backward(
#      92         tensors, grad_tensors, retain_graph, create_graph,
# ---> 93         allow_unreachable=True)  # allow_unreachable flag
#      94
#      95
#
# KeyboardInterrupt:

# %%
time_deriv_list, theta, coeff_vector_list = train(X_train, y_train, network, coeff_vector_list, sparsity_mask_list, library_config, optim_config)

# %%
sparse_coeff_vector, sparsity_mask, network = DeepMoD(X_train, y_train, network_config, lib_config, optim_config)
# Out:
# [autoreload of deepymod_torch.neural_net failed: Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/opt/conda/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/opt/conda/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/opt/conda/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/working/src/deepymod_torch/neural_net.py", line 153
#     writer.add_scalar('Regression '+str(idx), reg_cost_list[idx], iteration)
#     ^
# IndentationError: unexpected indent
# ]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-3bd46f328c80> in <module>
# ----> 1 sparse_coeff_vector, sparsity_mask, network = DeepMoD(X_train, y_train, network_config, lib_config, optim_config)
#
# NameError: name 'lib_config' is not defined

# %% [markdown]
# Now that DeepMoD has converged, it has found the following equation:

# %%
print('Final result:')
print(sparse_coeff_vector, sparsity_mask)
# Out:
# Final result:
# (tensor([[ 0.0994],
#         [-1.0001]], requires_grad=True),) (tensor([2, 5]),)
